# %%
# Final Exam

# %%
# 20202245

# %%
# Melany Rodriguez

# %%
#1. The Keynesian Income-Expenditure model

# %%
Consumption: C = C0 + bY^d
Investment:  I = I0 − hr
Government:  G = G0
Taxation:    T = tY
Export:      X = X0
Import:      M = mY^d
Expenditure: DA = C + I + G + X − M

Aggregate demand
𝐷𝐴 = C0 + bY^d + I0 − hr + G0 + X0 − mY^d
𝐷𝐴 =(b-m)(1-t)Y+C0 +I0 -hr+G0 +X0
𝐷𝐴 =(C0 +I0 +G0 +X0 −hr)+(b-m)(1-t)Y

Shortening the equation:
𝐷𝐴 = 𝛼0 + 𝛼1Y,
α0 =(C0 +I0 +G0 +X0 −hr)---intercept
α1 =(b-m)(1-t)-------------slope

# %%
Equilibrium equation for the Aggregate Income:
Y = DA
𝑌 = (C0 + I0 + G0 + X0 − hr) + (b - m)(1 - t)Y
Y - (b - m)(1 - t)Y = [C0 + I0 + G0 + X0 - hr]
[1 - (b-m)(1-t)]Y = [C0 + I0 + G0 + X0 - hr]

Y* = Equilibrium equation
Y* = (1/[1 - (b-m)(1-t)]) [C0 + I0 + G0 + X0 - hr]
K = (1/[1 - (b-m)(1-t)]) = keynesian multiplier

# %%
import numpy as np              
import matplotlib.pyplot as plt  

Y_size = 100
k = 20                
j = 10                
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100            
k = 33             
j = 5               
Ms = 35000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100
c = 20                
b = 0               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Short-Term Equilibrium Income")
ax.plot(Y, i_0)
ax.plot(Y, i, color = "none")
ax.plot(Y, i_1,linestyle='solid', color = "purple")
plt.axvline(x=54,  ymin=-100, ymax= 0.55, linestyle = "dotted", color = "black")
plt.axhline(y=3, xmin=-100, xmax= 0.54, linestyle = "dotted", color = "black")  
plt.axhline(y=-100, xmin=-100, xmax= 1, linestyle = "dotted", color = "black")
plt.text(80, 110, "DA = α0 + α1Y", color='black', size = 14)
plt.text(80, 80, " ↙", color ='black', size = 15)
plt.text(80, 40, "α1 = (b-m)(1-t)", color='black', size = 14)
plt.text(80, -140, " ↗", color ='black', size = 15)
plt.text(65, -170, "α0 =(C0 +I0 +G0 +X0 −hr)", color='black', size = 14)
plt.text(-20, -5, "DA^e", color='black', size = 18)
plt.text(-17, 330, "DA", color='black', size = 18)
plt.text(-20, -100, "α0", color='black', size = 18)
plt.text(51, -440, "Y^e", color='black', size = 18)
plt.text(100, -440, "Y", color='black', size = 18)
plt.text(3, -360, "45˚", color='black', size = 18)
plt.show()

# %%
Y^e and DA^e
represent the equilibrium of aggregate demand.

# %% [markdown]
# INTUITION:
# If the marginal propensity to consume increases, consumption increases, if consumption increases, aggregate demand rises. If aggregate demand rises, it means that it is greater than income or the level of supply, and to reach equilibrium the level of supply must increase.
# 'α1' increases due to the positive relationship and the product increases.
#
# MATH:
# ∆C = ∆bY - ∆btY
# ∆C = (Y - tY) ∆b
# ∆C = (1-t)Y ∆b
# ∆C/∆b = (1-t)Y

# %%
import numpy as np              
import matplotlib.pyplot as plt  

Y_size = 100
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#---------------------------------------------------

Y_size = 100
k = 30                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100            
k = 33             
j = 5               
Ms = 35000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100
c = 20                
b = 10               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="New Equilibrium Income if the Marginal Propensity to Consume increases ")
ax.plot(Y, i_2,linestyle='dashed' )
ax.plot(Y, i_0)
ax.plot(Y, i_1,linestyle='solid', color = "purple")
plt.axvline(x=54,  ymin=-100, ymax= 0.55, linestyle = "dotted", color = "black")
plt.axhline(y=3, xmin=-100, xmax= 0.54, linestyle = "dotted", color = "black")  
plt.axhline(y=-100, xmin=-100, xmax= 1, linestyle = "dotted", color = "black")
plt.text(80, 110, "DA = α0 + α1Y", color='black', size = 14)
plt.text(80, 80, " ↙", color ='black', size = 15)
plt.text(80, 40, "α1 = (b-m)(1-t)", color='black', size = 14)
plt.text(80, -140, " ↗", color ='black', size = 15)
plt.text(65, -170, "α0 =(C0 +I0 +G0 +X0 −hr)", color='black', size = 14)
plt.text(-20, -5, "DA^e", color='black', size = 18)
plt.text(-17, 330, "DA", color='black', size = 18)
plt.text(-20, -100, "α0", color='black', size = 18)
plt.text(51, -440, "Y^e", color='black', size = 18)
plt.text(100, -440, "Y", color='black', size = 18)
plt.text(3, -360, "45˚", color='black', size = 18)
plt.show()

# %%
#2. Different model

# %%
Consumption:      C = C0 + bY^d
Investment:       I = I0 
Government:       G = G0
Taxation:         T = t0
Aggregate demand: DA = C + I + G 

DA = Y
    
Y = C + I + G 
Y = C0 + bY^d + I0 + G0

The Equilibrium equation for the Aggregate Income
Y = (1/1-b) (C0 - bT + I0 + G0)

# %%
import numpy as np              
import matplotlib.pyplot as plt  

Y_size = 100
k = 20                
j = 10               
Ms = 25000             
P  = 14             
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#---------------------------------------------------

Y_size = 100
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100            
k = 33             
j = 5               
Ms = 40000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100
c = 20                
b = 10               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an expansion of Public Expenditure")
ax.plot(Y, i_2, linestyle='dashed' )
ax.plot(Y, i_0)
ax.plot(Y, i_1,linestyle='solid', color = "purple")
plt.axvline(x=48,  ymin=-100, ymax= 0.49, linestyle = "dotted", color = "black")
plt.axvline(x=64,  ymin=-100, ymax= 0.642, linestyle = "dotted", color = "black")
plt.axhline(y=27, xmin=-100, xmax= 0.642, linestyle = "dotted", color = "black")  
plt.axhline(y=-80, xmin=-100, xmax= 0.49, linestyle = "dotted", color = "black")
plt.text(80, 110, "DA1 = (α0 + ∆G) + α1Y", color='black', size = 14)
plt.text(80, -40, "DA0 = α0+α1Y", color='black', size = 14)
plt.text(-20, -5, "DA1^e", color='black', size = 18)
plt.text(-17, 330, "DA", color='black', size = 18)
plt.text(-20, -100, "DA0^e", color='black', size = 18)
plt.text(40, -490, "Y0^e", color='black', size = 18)
plt.text(60, -490, "Y1^e", color='black', size = 18)
plt.text(100, -490, "Y", color='black', size = 18)
plt.text(3, -410, "45˚", color='black', size = 18)
plt.show()

# %% [markdown]
# INTUITION
# If the government increases spending and at the same time increases taxes to keep the budget balanced, it means that the equilibrium income will increase by the same amount as the increase in spending.
# In this model, the expense does not depend on the people, the people have less income since the tax goes up. the state spends the money that has been collected on taxation.
#
# MATH:
# ∆Y = (1/1-b)(-b∆T + ∆G)
# ∆Y = (1-b/1-b)∆G
# ∆Y = ∆G

# %%
#IS-LM

# %%
Consumption: C = C0 + bY^d
Investment:  I = I0 − hr
Government:  G = G0
Taxation:    T = tY
Export:      X = X0
Import:      M = mY^d
Expenditure: DA = C + I + G + X − M
    
Aggregate demand
DA = C0 + bY^d + I0 − hr + G0 + X0 - mY^d
DA =(b-m)(1-t)Y + C0 + I0 - hr + G0 + X0
DA =(C0 + I0 + G0 + X0 - hr)+(b - m)(1 - t)Y

Y = DA
Y* = (C0 + I0 + G0 + X0 − hr) + (b - m)(1 - t)Y
Y* = Y - (b - m)(1 - t)Y = [C0 + I0 + G0 + X0 - hr]
Y* = [1 - (b-m)(1-t)]Y = [C0 + I0 + G0 + X0 - hr]
Y* = (1/(1-(b-m)(1-t))[C0 + I0 + G0 + X0 - hr]

# %% [markdown]
# INTUTITION:
# The income and interest rate values ​​balance the goods market. In equilibrium E0 there is a reduction in the interest rate and with it the intercept of the aggregate demand function increases upwards towards a new equilibrium. In other words, a reduction in the interest rate increases aggregate demand and with it, consumption and investment, so we say that aggregate demand causes production to rise.
#
# MATH:
# ∆Y = (k)(-)(h)∆r
# ∆Y = -kh ∆r < 0

# %%
import numpy as np              
import matplotlib.pyplot as plt  

Y_size = 100
k = 20                
j = 10               
Ms = 25000             
P  = 13             
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#---------------------------------------------------

Y_size = 100
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100            
k = 33             
j = 5               
Ms = 40000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100
c = 20                
b = 10               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Derivation of the IS curve from equilibrium Y=DA")
ax.plot(Y, i_2, linestyle='dashed' )
ax.plot(Y, i_0,)
ax.plot(Y, i_1, linestyle='solid', color = "purple")
plt.axvline(x=45.5,  ymin=-100, ymax= 0.47, linestyle = "dotted", color = "black")
plt.axvline(x=65.5,  ymin=-100, ymax= 0.65, linestyle = "dotted", color = "black")
plt.axhline(y=30, xmin=-100, xmax= 0.65, linestyle = "dotted", color = "black")  
plt.axhline(y=-100, xmin=-100, xmax= 0.465, linestyle = "dotted", color = "black")
plt.text(80, -70, "DA(r0)", color='black', size = 14)
plt.text(80, 40, "DA(r1)", color='black', size = 14)
plt.text(43, -80, "E0", color='black', size = 14)
plt.text(64, 60, "E1", color='black', size = 14)
plt.text(-17, 250, "DA", color='black', size = 18)
plt.text(43, -490, "Y0", color='black', size = 18)
plt.text(64, -490, "Y1", color='black', size = 18)
plt.text(110, -490, "Y", color='black', size = 18)
plt.text(3, -400, "45˚", color='black', size = 18)
plt.show()

# %%
#The IS curve from the Save-Investment Equilibrium

Y = C + I + G + X - M
We subtract the taxation "T":
Y - T = C + I - T + G + X - M  
Y^d   = C + I - T + G + X - M  
(Y^d - C) + (T - G) + (M - X) = I

Sp + Sg + Se = I0 - hr
S = I0 - hr
S(Y) = I(r)

(Y^d - C0 - bY^d) + (T - G0) + (mY^d - X0) = I0 - hr
[1 - (b-m)(1-t)]Y = [C0 + G0 + X0] = I0 - hr
hr = I0 - (1 - (b-m)(1-t))Y + (C0 + G0 + X0)
hr = 1/ h(C0 + G0 + I0 + X0) - 1/h (1 - (b-m)(1-t))Y

r = (ß0/h) - (ß1/h)Y
ß0 = C0 + G0 + I0 + X0 
ß1 = 1 - (b-m)(1-t)

# %%
#The derivation of the LM curve from equilibrium.

M0^s/P0 = kY - jr

r= f(Y)
jr=kj-M0^s/P0

r* = (k/j)Y - (1/j)(M0^s/P0)
r* = - (1/j)(M0^s/P0)+(k/j)Y

- (1/j)(M0^s/P0)--
(k/j)Y------------

If Y=0
r = (1/j)(M0^s/P0)
If the interest rate is 0
Y = (1/k)(M0^s/P0)

# %% [markdown]
# INTUITION:
# In the money market If income increases, the demand for money will also increase, so there will be excess demand in the money market because the supply is fixed. To return to equilibrium, the interest rate must increase to reduce excess demand.
# If income increases, the interest rate also increases to return to equilibrium in the market.
# In the goods market, an increase in income causes the demand for money to increase, it will be greater than the supply and the interest rate must be increased to return to equilibrium. And in another case, if the level of income falls, the demand for money contracts, with that the demand becomes less than the supply and the interest rate should be lowered for equilibrium.
#
# MATH:
# ∆r   = k/j∆Y
# ∆r/∆Y = k/j

# %%
import numpy as np               
import matplotlib.pyplot as plt  


Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#-------------------------------------   

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Derivation of the Money Market Equilibrium LM Curve", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0,  color= "green")
ax.vlines(x=59, ymin=-100, ymax=20,linestyle='dotted', colors='black')
ax.vlines(x=47, ymin=-100, ymax=-6,linestyle='dotted', colors='black')
ax.hlines(y=18, xmin=-8, xmax=60,linestyle='dotted', colors='black')
ax.hlines(y=-7, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.vlines(x=72, ymin=-100, ymax=45,linestyle='dotted', colors='black')
ax.hlines(y=46, xmin=-8, xmax=73,linestyle='dotted', colors='black')
plt.text(95, 100, "LM", color='black')
plt.text(70, 48, "C", color='black')
plt.text(45, -4, "A", color='black')
plt.text(57, 23, "B", color='black')
plt.text(60, -100, "Y1", color='black')
plt.text(48, -100, "Y0", color='black')
plt.text(73, -100, "Y2", color='black')
plt.text(-12, 18, "r1", color='black')
plt.text(-12, -7, "r0", color='black')
plt.text(-12, 46, "r2", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()

# %%
import numpy as np               
import matplotlib.pyplot as plt  


Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#-------------------------------------   

Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

#---------------------------------------------------
Y_size = 100
c = 45                
b = 0.05               
           
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 2             
h = 1  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


#---------------------------------------------------

Y_size = 100
c = 70                
b = 0.05               
           
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 90
X_bar = 2             
h = 1  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Derivation of the Money Market Equilibrium LM Curve", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i,)
ax.plot(Y, i_2)
ax.plot(Y, i_1, linestyle='dotted',color= "green")
ax.vlines(x=59, ymin=-150, ymax=200,linestyle='solid', colors='black')
ax.hlines(y=18, xmin=-8, xmax=59,linestyle='dotted', colors='black')
ax.hlines(y=-30, xmin=-8, xmax=59,linestyle='dotted', colors='black')
ax.hlines(y=63, xmin=-8, xmax=59,linestyle='dotted', colors='black')
plt.text(95, 5, "M2^d(Y2)", color='black')
plt.text(95, -45, "M1^d(Y1)", color='black')
plt.text(95, -95, "M0^d(Y0)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()

# %%
#DA-OA Model

# %%
Aggregate demand
IS : 
r = (ß0/h) - (ß1/h)Y

ß0 = C0 + G0 + I0 + X0 
ß1 = 1 - (b-m)(1-t)

LM:
r = - (1/j)(M0^s/P0)+(k/j)Y

Endogenous: r, Y
Exogenous: everything else

# %%
Equalize:
- (1/j)(M0^s/P0)+(k/j)Y = (ß0/h) - (ß1/h)Y

Y^e = jß0/kh+jß1 + (h/kh+jß1)M0^s/P0

r = (ß0/h) - (ß1/h)(jß0/kh+jß1 + (h/kh+jß1)M0^s/P0)
r^e = kß0/kh+jß1 - (ß1/kh+jß1)M0^s/P0

Y^e y r^e represent the equilibrium in the IS-LM model
The slope of the IS curve is negative and the slope
of the LM is positive.

# %%
Without "r", P:
P = h(M0^s)/-jß0+(jß1+hk)Y

The aggregate demand equation
Y = jß0/jß1+hk + (h(M0^s)/jß1+hk)1/P

# %%
import numpy as np               
import matplotlib.pyplot as plt  


Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#-------------------------------------   

Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Simultaneous equilibrium in the goods and money markets", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", label="LM_0")
ax.plot(Y, i, "r-",label="IS_0")
ax.vlines(x=47, ymin=-120, ymax=-3,linestyle='dotted', colors='black')
ax.hlines(y=-4, xmin=-8, xmax=47,linestyle='dotted', colors='black')
plt.text(52, -9, 'E=( Y0, r0 )', color='black')
ax.legend()  
plt.show()

# %% [markdown]
# What happens with the endogenous variables if 𝐺 decreases?
#
# INTUITION:
# If there is a decrease in the variable G, there will be a decrease in aggregate demand. If it decreases, it will be less than production. If production falls, income also so there is a decrease in the demand for money. It will be less than the money supply and the interest rate will have to be lowered to return to equilibrium.
# IS curve shifts to the left
# LM curve does not shift
#
# MATH:
# ∆Y = [j/kh+jß1]∆G
# ∆r = [k/kh+jß1]∆G

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 40                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="DA-OA Model: Effects of an Expansionary Fiscal Policy (dG0 > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, linestyle='solid', label="LM_0", color='green')
ax.plot(Y, i, linestyle='solid', label="IS_0", color='green')
ax.plot(Y, i_2, linestyle='dashed',label="LM_2", color= "skyblue")
ax.plot(Y, i_1, linestyle='dashed',label="LM_1", color= "skyblue")
ax.vlines(x=55.5, ymin=-100, ymax=82,linestyle='dotted', colors='black')
ax.hlines(y=78, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, 'LM (P0)', color='black')
plt.text(20, 160, "LM'(P1)", color='black')
plt.text(20, 0, "IS'", color='black')
plt.text(20, -40, "IS", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()

# %%
import numpy as np               
import matplotlib.pyplot as plt  


Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#-------------------------------------   

Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

#---------------------------------------------------
Y_size = 100
c = 45                
b = 0.05               
           
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 2             
h = 1  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effect of a decrease in Government Spending", xlabel=r'Y', ylabel=r'P')
ax.plot(Y, i_0,  label="LM_0", color='green')
ax.plot(Y, i, label="IS_2", linestyle = 'dotted')
ax.plot(Y, i_1, linestyle='solid',color= "green", label="IS_1")
ax.vlines(x=59, ymin=-100, ymax=20,linestyle='dotted', colors='black')
ax.vlines(x=47, ymin=-100, ymax=-6,linestyle='dotted', colors='black')
ax.hlines(y=18, xmin=-8, xmax=60,linestyle='dotted', colors='black')
ax.hlines(y=-7, xmin=-8, xmax=48,linestyle='dotted', colors='black')
plt.text(95, 100, "LM", color='black')
plt.text(95, -45, "IS", color='black')
plt.text(95, -95, "IS'", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()

# %%
#What happens with the endogenous variables if M0^s decreases?
INTUITION:
If the quantity of money is reduced, the interest rate rises, 
this causes investment to be reduced as well as aggregate demand,
so production is also reduced.

MATH:
∆Y^e = [h/kh+jß1](1/P0) ∆M0^s 
∆r^e = [ß1/kh+jß1](1/P0)∆M0^s

# %%
import numpy as np              
import matplotlib.pyplot as plt  

Y_size = 100
k = 20                
j = 10                
Ms = 10000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------
Y_size = 100
             
k = 20                
j = 10               
Ms = 15000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------
Y_size = 100
             
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100
c = 30                
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 30            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

#---------------------------------------------------

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="OA-DA Model: Effects of a Contractionary Monetary Policy (dM^s0 < 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_2, linestyle='dotted', label="LM_2", color = 'blue')
ax.plot(Y, i, label="IS_0", color = 'blue')
ax.plot(Y, i_1, linestyle='dashed', color = "purple")
ax.plot(Y, i_0, color = "blue")
ax.vlines(x=55, ymin=-100, ymax=10,linestyle='dotted', colors='black')
ax.hlines(y=35, xmin=-8, xmax=43,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=8, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.vlines(x=48, ymin=-100, ymax=26,linestyle='dotted', colors='black')
ax.vlines(x=42.5, ymin=-100, ymax=31,linestyle='dotted', colors='black')
plt.text(20, 0.5, 'LM (M1, P0)', color='black')
plt.text(20, 80, "IS", color='black')
plt.text(20, -40, "LM (M1, P1)", color='black')
plt.text(20, -70, "LM (Mo, Po)", color='black')
plt.show()

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="OA-DA Model: Effects of a Contractionary Monetary Policy(dMs0 < 0)", xlabel=r'Y', ylabel=r'P')
ax.plot(Y, i_0,  linestyle='none')
ax.plot(Y, i, linestyle='solid', color = 'blue')
ax.plot(Y, i_2, linestyle='dashed', color= "purple")
ax.plot(Y, i_1, linestyle='solid', color = 'blue')
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, "DA'", color='black')
plt.text(20, 120, "OA", color='black')
plt.text(20, -40, "DA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()

# %%
#IS-LM Model with exogenous interest set by the central bank

# %%
Y=      C + I + G + X - M
C=      C0 + b(1−t)Y
I =     I0 − hr
G =     tY
X =     X0
M =     mY
M0^s/P0=kY - jr

# %%
Find the equilibrium equation of Y and MS0

Y*       =  C0 + b(1−t)Y + I0 - hr0 + tY + X0 - mY
M0^s/P0* =  kY - jr0

# %%
import numpy as np               
import matplotlib.pyplot as plt  


Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#-------------------------------------   

Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Simultaneous equilibrium in the goods and money markets", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", label="LM_0")
ax.plot(Y, i, "r-",label="IS_0")
ax.vlines(x=47, ymin=-120, ymax=-6,linestyle='dotted', colors='black')
ax.hlines(y=-7, xmin=-8, xmax=100,linestyle='solid', colors='black')
plt.text(41, 7, 'E=( Y0, r0 )', color='black')
plt.text(80, 2, 'exogenous value r', color='black')
ax.legend()  
plt.show()

# %%
#What happens with the endogenous variables if 𝐺 decreases? 

INTUITION:
If spending decreases, aggregate demand also decreases.
so it will be less than production. to reach equilibrium
production must be reduced.

MATH:
∆Y = [j/kh+jß1]∆G 
∆r = [k/kh+jß1]∆G

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 40                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Contractionary monetary policy)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0,  linestyle='dashed', label="LM_0")
ax.plot(Y, i, linestyle='none', label="IS_0")
ax.plot(Y, i_2, linestyle='solid', color= "green")
ax.plot(Y, i_1, linestyle='solid', color= "green")
ax.vlines(x=48, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=63, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=45, xmin=-8, xmax=56,linestyle='dotted', colors='black')
ax.vlines(x=57, ymin=-100, ymax=48,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 0, "LM'(P1)", color='black')
plt.text(20, -40, "LM (P0)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()

# %%
#What happens with the endogenous variables if r decreases? 

INTUITION:
If the interest rate is reduced, investment increases and 
excess demand is generated. Aggregate demand increases and is 
greater than production so to reestablish the balance,
the production or supply of money must increase. 
An expansionary monetary policy is generated.

MATH:
∆Y = [j/kh+jß1]∆G 
∆r = [k/kh+jß1]∆G

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 8              
Ms = 1000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 8               
Ms = 8000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 40                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Short-run equilibrium of an expansionary monetary policy", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0,  linestyle='solid', label="LM_0", color='brown')
ax.plot(Y, i, linestyle='solid', label="IS_0", color='brown')
ax.plot(Y, i_2, linestyle='none', color= "blue")
ax.plot(Y, i_1, linestyle='dashed', color= "blue")
ax.vlines(x=50, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=59, xmin=-8, xmax=100,linestyle='dashed', colors='black')
ax.hlines(y=85, xmin=-8, xmax=100,linestyle='solid', colors='black')
ax.vlines(x=35.5, ymin=-100, ymax=84,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 25, "LM(M0^s)", color='black')
plt.text(20, -30, "LM (M1^s)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
