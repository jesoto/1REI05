# %% [markdown]
# # Final Exam

# %% [markdown]
# Alessa Camila Garcia Garcia 20171501

# %% [markdown]
# # The Keynesian Income-Expenditure model

# %% [markdown]
# ## 1.The equations of the Income-Expenditure model and the Aggregate Demand function:

# %% [markdown]
# Find the Equilibrium equation for the Aggregate Income. Please, write all the equations in steps.

# %% [markdown]
# ### Agregate demand

# %% [markdown]
# $DA$=$C$+$I$+$G$+($X$−$M$)

# %% [markdown]
# $DA$=$(C_{0}+I_{0}+G_{0}+X_{0}-h_{r})$+$(b-m)(1-t)Y$

# %% [markdown]
# $DA$=$α_{0}$+$α_{1}Y$

# %% [markdown]
# $α_{0}$ is the intercept; and $α_{1}$, the slope

# %% [markdown]
# ### Equilibrium formula

# %% [markdown]
# $Y$=$(C_{0}+I_{0}+G_{0}+X_{0}-h_{r})$+$(b-m)(1-t)Y$
#
# $Y$=$[1-(b-m)(1-t)]^{-1}$$[C_{0}+I_{0}+G_{0}+X_{0}-h_{r}]$

# %% [markdown]
# Using Python, plot the next figure and explain what  and  represent in the graphic:

# %% [markdown]
# $Y^{e}$ and $DA^{e}$ in the function of Aggregate Demand

# %%
import numpy as np               
import matplotlib.pyplot as plt 
Y_size = 100

C0 = 20   
G0 = 24   
I0 = 10   
X0 = 2    
h = 1     
m = 0.05   
t = 0.9   
b = 2.1   
r=0.2

a_0 = (C0+I0+G0+X0-h*r)
a_1 = (b-m)*(1-t)

Y = np.arange(Y_size)

# %%
def P_AD(a_l, a_1, Y):
    P_AD = (a_0+(a_1*Y))
    return P_AD

DA = P_AD(a_0, a_1, Y)
DA

def P_45(Y):
    P_45 = Y
    return P_45

P_45 = P_45(Y)

# %%
y_max = np.max(P_AD)
v = [0, Y_size, 0, y_max]
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Aggregate Demand", xlabel= r'Y', ylabel= r'DA')
ax.plot(Y, DA, "k-", label = "DA",color="blue")  
ax.plot(Y, P_45, "k-") 

plt.axvline(x=71.45,  ymin= 0, ymax= 0.71, linestyle = ":", color = "black")
plt.axhline(y=71.45, xmin= 0, xmax= 0.71, linestyle = ":", color = "black")
plt.axhline(y=56.8, xmin= 0, xmax= 0.71, linestyle = ":", color = "black")
plt.text(60, 88, ' DA=(α_0)+(α_1)Y ', fontsize=14, color='black')
plt.text(79, 77, ' α_1=(b-m)+(1-t) ', fontsize=14, color='black')
plt.text(70, 55, ' α_0=(C0+I0+G0+X0-hr) ', fontsize=14, color='black')
plt.text(-14, 62, "DA", color='blue', size = 15)
plt.text(-12, 54, "α0", color='black', size = 12)
plt.plot(0, 0, marker="o", color="black", label = "45")
plt.plot(71.5, 71.5, marker="o", color="black")
plt.text(1, -1.6, ')45', fontsize = 14, color = 'black')


ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/2010748977.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, DA, "k-", label = "DA",color="blue")

# %% [markdown]
# Intuitive explanation: $b$ $↑$ $→$ $C$ $↑$
#
# - when  the marginal propensity to consume is higher, the greater the consumption.
#
# Mathematical explanation: $ΔC$=$(1-t)yΔb$

# %% [markdown]
# What happens if the Marginal Propensity to Consume increases. Explain using intuition, Math, and a Figure.

# %% [markdown]
# Intuition:
# Δb↑→  C↑→  DA ↑→  DA > Y→  Y ↑
#
# Math:
#
#     ΔC =  ΔbY -  ΔbtY
#
#    ΔC= (Y - tY)Δb
#
#  ΔC\Δb = (Y - tY)
#
#    Δb> 0
#
#    Δb↑= ΔC↑

# %%
### effects of Increased Marginal Propensity to Consume

# %%
Y_size = 100
k = 20                
j = 10               
Ms = 20             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#---------------------------------------------------

Y_size = 100
k = 30                
j = 10               
Ms = 20             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100            
k = 33             
j = 5               
Ms = 350             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100
c = 20                
b = 10               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="New Equilibrium Income if the Marginal Propensity to Consume increases ")
ax.plot(Y, i_2,linestyle='dashed',color="red" )
ax.plot(Y, i_0,color="black")
plt.show()

# %% [markdown]
# if the Marginal Propensity to Consume increases.
#
# Intuitive explanation:
#
# $DA↓$ $→$ $DA$ $<$ $Y$ $→$ $Y↓$
#
# if the aggregate demand is higher than the product, it must increase, if the demand is less than the product, it must decrease.
#
# Mathematical explanation:
#
# $Y=DA$
#
# $Y$=$(C_{0}+I_{0}+G_{0}+X_{0}-h_{r})$+$(b-m)(1-t)Y$
#
# $Y$=$[1-(b-m)(1-t)]^{-1}$$[C_{0}+I_{0}+G_{0}+X_{0}-h_{r}]$

# %% [markdown]
# ## 2. Now you have a different model

# %% [markdown]
# ### Find the Equilibrium equation for the Aggregate Income. Please, write all the equations in steps. Explain using intuition, Math, and a Figure.

# %% [markdown]
# $DA$=$C$+$I$+$G$
#
# $DA$=$C0$+$b$*$(Y-T0)$+$I0$+$G0$
#
#
# $C0$+$b$*$Y-b$*$T0$+$I0$+$G0$=$Y$
#
#
# $C0-b$*$T0$+$I0$+$G0$=$Y$*$(1-b)$
#
#
# $Y$=$1/(1-b)$*$(C0-b*T0+I0+G0)$

# %% [markdown]
# Using Python, plot the equilibrium and explain what Ye and DAe

# %% [markdown]
# ### $Y^{e}$ and $DA^{e}$ in the function of Aggregate Demand, but it doesn't include exports or imports.

# %%
Y_size = 100

C0 = 10   
G0 = 18   
I0 = 5   
T0 = 1   
b = 0.5   

alfa0 = (C0+I0+G0-(T0*b))
alfa1 = b

Y = np.arange(Y_size)

def P_AD(alfa0, alfa1, Y):
    P_AD = (alfa0+(alfa1*Y))
    return P_AD

P_AD = P_AD(alfa0, alfa1, Y)
P_AD



def P_45(Y):
    P_45 = Y
    return P_45

P_45 = P_45(Y)
P_45

y_max = np.max(P_AD)
v = [0, Y_size, 0, y_max]
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Aggregate Demand", xlabel= r'Y', ylabel= r'DA')
ax.plot(Y, P_AD, "k-", label = "DA",color = 'blue')  
ax.plot(Y, P_45, "k-", label = "DA") 


plt.plot(0, 0, marker="o", color="black", label = "45")
plt.text(1, -1.6, ')45', fontsize = 14, color = 'black')

plt.axvline(x=65,  ymin= 0, ymax= 0.65, linestyle = ":", color = "black")
plt.axhline(y=65, xmin= 0, xmax= 0.65, linestyle = ":", color = "black")
plt.axhline(y=32.5, xmin= 0, xmax= 0.65, linestyle = ":", color = "black")


ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1858386897.py:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, P_AD, "k-", label = "DA",color = 'blue')

# %% [markdown]
# ### What happens with the endogenous variables if the government increases its spending and at the same time increases taxes by the same magnitude to keep the budget balanced; that is Δ𝑇 = Δ𝐺. Explain using intuition, Math, and a Figure.

# %%
Y_size = 100
c = 20                 
b = 0.2                
m = 0.2           
T = 1                  
I_bar = 10            
G_bar = 8              
X_bar = 2              
h = 5                 
Y = np.arange(Y_size)  

"3|DEFINE AND POPULATE THE IS-SCHEDULE"
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

Y_size = 100
c = 20                
b = 0.2               
            
m = 0.2            
T = 10                 
I_bar = 10            
G_bar = 10             
X_bar = 2              
h = 5  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

"4|PLOT THE IS-SCHEDULE"
y_max = np.max(i)
x_max = Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Graph of the increase in government spending and taxes", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i, "k-",Label="IS_0")
ax.plot(Y, i_1, "b-",linestyle='dotted',Label="IS_1")
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())   

plt.axis(v)         
plt.legend()        
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1015847111.py:56: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(Y, i, "k-",Label="IS_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1015847111.py:57: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "b-",linestyle='dotted',Label="IS_1")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1015847111.py:57: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(Y, i_1, "b-",linestyle='dotted',Label="IS_1")
# No handles with labels found to put in legend.

# %% [markdown]
# # IS-LM

# %% [markdown]
# Show the derivation of the IS curve from equilibrium Y=DA. Explain using intuition, Math, and a Figure.

# %% [markdown]
# $DA$=$C+I+G+X-M$
#
#
# $Y$=$C0+b*Y^d+I0-h*r+G0+X0-m*Y^d$
#
#
# Y=C0+I0-h*r+G0+X0+(b-m)*(1-t)*Y
#
#
# Y=(1/(1-(b-m)(1-t)))(C0+I0+G0+X0-h*r)

# %% [markdown]
# Derive the IS curve from the Save-Investment Equilibrium.

# %% [markdown]
# $Sp+Sg+Se=I=I0-h*r$
#
#
# Y^d-(C0+b*Y^d)+T-G+(m*Y^d-X0)=I0-h*r
#
#
# (1-(b-m)*(1-t))*Y-(C0+G0+X0)=I0-h*r
#
#
# h*r=I0-(1-(b-m)*(1-t))*Y+(C0+G0+X0)
#
#
# h*r=(C0+G0+I0+X0)-(1-(b-m)*(1-t))*Y
#
#
# IS: r=(1/h)(C0+G0+I0+X0)-(1/h)(1-(b-m)*(1-t))*Y

# %%
Show the derivation of the LM curve from equilibrium Ma = Md. Explain using intuition, Math, and a Figure.

# %% [markdown]
# # DA-OA Model

# %%
Use the next Equations and find the equilibrium

# %%
Find the equilibrium equation of Ye , Pe and re .

# %% [markdown]
# M/P*1/k+j/k*r=(c+I+G)/(1-b*(1.t))-h/(1.b*(1-t))*r
#
#
# r(j/k+h/(1-b*(1-t)))=(c+I+G)/(1-b*(1-t))-Ms/p*1/k

# %% [markdown]
# r=(c+I+G)/(j*(1-b*(1-t)))-(Ms*k(1-b*(1-t)))/(P*k*j*(1-b*(1-t))+k*h)
#
#
# r^e=(a0)/(j*(a1))-Ms/P*(a1)/(j*(a1)+h)
#
#
#
# $Y^e=M/P*1/k+j/k*(r^e)$

# %% [markdown]
# Graph the Equilibrium in the IS-LM markets and also in the aggregate demand and supply. (In one figure, you have to use the r and Y axis, and in the other one, the P and Y-axis)

# %%
"|DEFINE PARAMETERS OF LM_0 AND ARRAYS"
# Parameters
Y_size = 100
k = 20                
j = 10                
Ms = 20000             
P  = 20                
# Arrays
Y = np.arange(Y_size)  # Array values of Y

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
LM_0 = i_LM( k, j, Ms, P, Y)
#-------------------------------------   
"|DEFINE PARAMETERS OF LM_1 AND ARRAYS"
# Parameters
Y_size =100
k = 20                
j = 10                
Ms = 10000            
P  = 20               
# Arrays
Y = np.arange(Y_size)  # Array values of Y
#-------------------------------------
"3|DEFINE AND POPULATE THE LM-SCHEDULE"
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
LM_1 = i_LM( k, j, Ms, P, Y)


#------------------------------------- 

"|DEFINE PARAMETERS OF IS_0 AND ARRAYS"
Y_size = 100
c = 20                 
b = 0.01               
t = 0.9                
I_bar = 10             
G_bar = 50             
h = 1                  # Investment slope wrt to i
# Arrays
Y = np.arange(Y_size)  # Array values of Y

#------------------------------------------------------------------
"3|DEFINE AND POPULATE THE IS-SCHEDULE"
def i_IS(c, b, t, I_bar, G_bar, h, Y):
    i_IS = -((1-b*(1-t))*Y/h)+(c+I_bar+G_bar)/h
    return i_IS

def Y_IS(c, b, t, I_bar, G_bar, h, i):
    Y_IS = (c+I_bar+G_bar)/(i-b(1-t))-(h*i)/(i-b(1-t))
    return Y_IS


i = i_IS(c, b, t, I_bar, G_bar, h, Y)

#---------------------------------------------------
"|DEFINE PARAMETERS OF IS_1 AND ARRAYS"
Y_size = 100
c = 20                 # Autonomous consumption
b = 0.01                # Marginal propensity to consume
t = 0.9                  # Taxes
I_bar = 10             # Investment intercept (when i = 0)
G_bar = 25             # Government spending
h = 1                  # Investment slope wrt to i
# Arrays
Y = np.arange(Y_size)  # Array values of Y

"3|DEFINE AND POPULATE THE IS-SCHEDULE"
def i_IS(c, b, t, I_bar, G_bar, h, Y):
    i_IS = -((1-b*(1-t))*Y/h)+(c+I_bar+G_bar)/h
    return i_IS

def Y_IS(c, b, t, I_bar, G_bar, h, i):
    Y_IS = (c+I_bar+G_bar)/(i-b(1-t))-(h*i)/(i-b(1-t))
    return Y_IS


i_1 = i_IS(c, b, t, I_bar, G_bar, h, Y)


"PLOT THE IS-SCHEDULE"
y_max = np.max(i)

v = [0, Y_size, 0, y_max]                       # Set the axes range
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="LM SCHEDULE", xlabel=r'Y', ylabel=r'i')
ax.plot(Y, LM_0, "b-", label="LM_0",color="green")
ax.plot(Y, LM_1, "b-",linestyle = ":", label="LM_1")
ax.plot(Y, i, "r-",label="IS_0",color="purple")
ax.plot(Y, i_1, "r-",linestyle=':',label="IS_1")
ax.yaxis.set_major_locator(plt.NullLocator())   # Hide ticks
ax.xaxis.set_major_locator(plt.NullLocator())   # Hide ticks
plt.plot(60.02, 20.04, marker="o", color="black", label = "E0")
plt.plot(51.68, 3.37, marker="o", color="black", label = "E1")
plt.plot(43.35, 36.7, marker="o", color="black", label = "E2")

plt.text(60.02, 25.20, 'E0', fontsize = 14, color = 'black')
plt.text(51.68, 9.52, 'E1', fontsize = 14, color = 'black')
plt.text(43.35, 43.12, 'E2', fontsize = 14, color = 'black')

ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/2318237406.py:90: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, LM_0, "b-", label="LM_0",color="green")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/2318237406.py:91: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, LM_1, "b-",linestyle = ":", label="LM_1")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/2318237406.py:92: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",label="IS_0",color="purple")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/2318237406.py:93: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle=':',label="IS_1")

# %% [markdown]
# What happens with the endogenous variables if G decreases? Explain using intuition, Math, and a Figure. (In one figure, you have to use the r and Y axis, and in the other one, the P and Y-axis)

# %% [markdown]
# intuition
# G →DA ↓ →DA>Y →Y ↓
#
# Y ↑ →Md ↓ →Md<Ms →r ↓
#
# r ↓ →I ↑ →DA ↑DA>Y →Y ↑

# %% [markdown]
# mathematics
# ΔPe=0
#
# Δr= ΔG/(j*alpha1)<0
#
# $ΔYe=j/k* Δr<0$

# %% [markdown]
# What happens with the endogenous variables if Ma0 decreases? Explain using intuition, Math, and a Figure. (In one figure, you have to use the r and Y axis, and in the other one, the P and Y-axis)

# %% [markdown]
# intuition
#
# $Ms ↓ →(Ms/P) <Md →r ↑$
#
# $r ↑ →I ↓ →DA ↓ →DA<Y →Y ↓$

# %% [markdown]
# mathematics
#
# ΔP=0
#
# $Δr=- ΔMs/P*(alpha1/(j*(alpha1)+h)>0$
#
# $ΔY= ΔMs/P*1/k+j/k*r<0$

# %% [markdown]
# # IS-LM Model with exogenous interest set by the central bank

# %% [markdown]
# Now you have to use the model below. But now the interest rate  and  are exogenous. Because  is the instrument of monetary policy. The endogenous variables of this model are Y and Ma0.

# %% [markdown]
# Find the equilibrium equation of Y and Ma0.

# %% [markdown]
# $Y=C+I+G+X-M$
#
# Y=C0+b*(1-t)*Y+I0-h*r+t*Y+X0-m*Y
#
#
# Y*(1-b*(1-t)-t+m9=C0+I0-h*r+X0
#
#
# $IS: Y=(C0+I0-h*r+X0+G0)/(1-b*(1-t)-t+m)$
#
#
# $LM: r=k/j*Y-Ms/P*1/j$
#
#
# Equilibrium Y=r :
#
# $Y(1+h*k/j*(alpha1)=(alpha0)/(alpha1)$

# %%
Graph the Equilibrium in the IS-LM markets and draw a horizontal line for the exogenous value of r.

# %%
"|DEFINE PARAMETERS OF LM_0 AND ARRAYS"

# Parameters
Y_size = 100
            
k = 0              
j = 10                
Ms = 20000             
P  = 80      

#(Ms/P)/j + k/j*Y=re
# Arrays
Y = np.arange(Y_size)  # Array values of Y

"|DEFINE AND POPULATE THE LM-SCHEDULE"
def i_LM( k, j, Ms, P, Y):
    i_LM = (Ms/P)/j + k/j*Y
    return i_LM
LM_0 = i_LM( k, j, Ms, P, Y)
#-------------------------------------  
"|DEFINE PARAMETERS OF LM_1 AND ARRAYS"
# Parameters
Y_size = 100
            
k = 0              
j = 10                
Ms = 30000             
P  = 80               
# Arrays
Y = np.arange(Y_size)  # Array values of Y

"|DEFINE AND POPULATE THE LM-SCHEDULE"
def i_LM( k, j, Ms, P, Y):
    i_LM = (Ms/P)/j + k/j*Y
    return i_LM
LM_1 = i_LM( k, j, Ms, P, Y)
#-------------------------------------  
"|DEFINE PARAMETERS OF IS_0 AND ARRAYS"
Y_size = 100
c = 20                 
b = 0.01               
t = 0.9                  
I_bar = 10             
G_bar = 25  
X_bar=2
h = 1                  
# Arrays
Y = np.arange(Y_size)  

"3|DEFINE AND POPULATE THE IS-SCHEDULE"

def i_IS(c, b, t, I_bar, G_bar, X_bar, h, Y):
    i_IS = -((1-b*(1-t))*Y/h)+(c+I_bar+G_bar+X_bar)/h
    return i_IS

def Y_IS(c, b, t, I_bar, G_bar, X_bar, h, i):
    Y_IS = (c+I_bar+G_bar+X_bar)/(i-b(1-t))-(h*i)/(i-b(1-t))
    return Y_IS


i_1 = i_IS(c, b, t, I_bar, G_bar, X_bar, h, Y)


"|DEFINE PARAMETERS OF IS_2 AND ARRAYS"
Y_size = 100
c = 20                 
b = 0.01               
t = 0.9                  
I_bar = 10             
G_bar = 15  
X_bar=2
h = 1                  
# Arrays
Y = np.arange(Y_size)  

"3|DEFINE AND POPULATE THE IS-SCHEDULE"

def i_IS(c, b, t, I_bar, G_bar, X_bar, h, Y):
    i_IS = -((1-b*(1-t))*Y/h)+(c+I_bar+G_bar+X_bar)/h
    return i_IS

def Y_IS(c, b, t, I_bar, G_bar, X_bar, h, i):
    Y_IS = (c+I_bar+G_bar+X_bar)/(i-b(1-t))-(h*i)/(i-b(1-t))
    return Y_IS

i_2 = i_IS(c, b, t, I_bar, G_bar, X_bar, h, Y)

"|DEFINE PARAMETERS OF IS_3 AND ARRAYS"
Y_size = 100
c = 20                 
b = 0.01               
t = 0.9                  
I_bar = 30             
G_bar = 25  
X_bar=2
h = 1                  
# Arrays
Y = np.arange(Y_size)  

"3|DEFINE AND POPULATE THE IS-SCHEDULE"

def i_IS(c, b, t, I_bar, G_bar, X_bar, h, Y):
    i_IS = -((1-b*(1-t))*Y/h)+(c+I_bar+G_bar+X_bar)/h
    return i_IS

def Y_IS(c, b, t, I_bar, G_bar, X_bar, h, i):
    Y_IS = (c+I_bar+G_bar+X_bar)/(i-b(1-t))-(h*i)/(i-b(1-t))
    return Y_IS

i_3 = i_IS(c, b, t, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_1)

v = [0, Y_size, 0, y_max]                       # Set the axes range
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="LM SCHEDULE", xlabel=r'Y', ylabel=r'MS')
ax.plot(Y, LM_0, "b-", color="black", label="LM_0")
ax.plot(Y, LM_1, "b-",linestyle=':', color="blue", label="LM_1")
ax.plot(Y, i_1, "b-", color="purple", label="i_0")
ax.plot(Y, i_2, "b-",linestyle='-', color="red", label="i_1")
ax.plot(Y, i_3, "b-",linestyle='--', color="blue", label="i_2")

plt.plot(32.03, 25, marker="o", color="black", label = "E0")
plt.plot(22.02, 25, marker="o", color="black", label = "E1")
plt.plot(39.54, 37.5, marker="o", color="black", label = "E2")

plt.text(32.03, 26, 'E0', fontsize = 14, color = 'black')
plt.text(22.02, 26, 'E1', fontsize = 14, color = 'black')
plt.text(39.54, 38.5, 'E2', fontsize = 14, color = 'black')

#---------------------------------------------------
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:117: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, LM_0, "b-", color="black", label="LM_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:118: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, LM_1, "b-",linestyle=':', color="blue", label="LM_1")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:118: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, LM_1, "b-",linestyle=':', color="blue", label="LM_1")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:119: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "b-", color="purple", label="i_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:120: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "b-",linestyle='-', color="red", label="i_1")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:120: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "b-",linestyle='-', color="red", label="i_1")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:121: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_3, "b-",linestyle='--', color="blue", label="i_2")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/1213957373.py:121: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_3, "b-",linestyle='--', color="blue", label="i_2")
# Text(39.54, 38.5, 'E2')

# %% [markdown]
# What happens with the endogenous variables if G decreases? Explain using intuition, Math, and a Figure.

# %% [markdown]
# intuition
# $G ↓→DA ↓ →DA<Y →Y ↓$
#
# r=0
#
# autonomous spending decreases → aggregate Demand decreases in the goods market.

# %% [markdown]
# mathematics
#
# $ΔY= ΔG*j/(j*(a1)+h*k)<0$
#
# Δr=0

# %% [markdown]
# What happens with the endogenous variables if r decreases? Explain using intuition, Math, and a Figure.

# %%
"2|DEFINE PARAMETERS AND ARRAYS"
Y_size = 100
c = 20                 
b = 0.20                
            
m = 0.2            
T = 1                  
I_bar = 10            
G_bar = 8              
X_bar = 2              
h = 5                  
Y = np.arange(Y_size)  

"3|DEFINE AND POPULATE THE IS-SCHEDULE"
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#--------------------------------------------------------------
Y_size = 100
c = 20                 
b = 0.35                
             
m = 0.2            
T = 1                 
I_bar = 10             
G_bar = 8              
X_bar = 2             
h = 5  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

"4|PLOT THE IS-SCHEDULE"
y_max = np.max(i)
x_max = Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, 0)

v = [0, x_max, 0, y_max]                        # Set the axes range
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="The effects of the decrease in the interest rate", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i, "k-",linestyle='dashed',Label="Md_1", color='green')
ax.plot(Y, i_1, "r-", Label="Md_0", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())   # Hide ticks
ax.xaxis.set_major_locator(plt.NullLocator())   # Hide ticks

plt.axis(v)         
plt.legend()        
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/3606705576.py:56: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "k-",linestyle='dashed',Label="Md_1", color='green')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/3606705576.py:56: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, i, "k-",linestyle='dashed',Label="Md_1", color='green')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/3606705576.py:56: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(Y, i, "k-",linestyle='dashed',Label="Md_1", color='green')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/3606705576.py:57: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-", Label="Md_0", color='black')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6116/3606705576.py:57: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(Y, i_1, "r-", Label="Md_0", color='black')
# No handles with labels found to put in legend.

# %% [markdown]
# Intuitive explanation:
# $r ↓ → I↑ → DA↑ → DA>Y → Y ↑$

# %% [markdown]
# Mathematical explanation:
#
# $ΔY=-kh Δr<0$
