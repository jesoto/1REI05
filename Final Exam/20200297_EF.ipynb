# %% [markdown]
# # FINAL EXAM
#
# ### Name: Alexandra Patricia Gonzalez Saldaña
# ### Code: 20200297

# %% [markdown]
# ## 01: The Keynesian Income-Expenditure model
#
# #### Find the Equilibrium equation for the Aggregate Income. Please, write all the equations in steps

# %% [markdown]
# Derivation:
#
# $$ Y = DA $$
#
# $$ DA = C + I + G + X - M $$
#
# $$ Y = C + I + G + X - M $$
#
# $$ Y = \frac{1}{1 - (b-m)(1-t)}(C_0 + G_0 + I_0 + X_0) - \frac{h}{1 - (b-m)(1-t)}r $$
#
# $$ r = \frac{1}{h}(C_0 + G_0 + I_0 + X_0) - \frac{1 - (b - m)(1 - t)}{h}Y $$

# %% [markdown]
# And can be simplified to:
#
# $$ r = \frac{B_0}{h} - \frac{B_1}{h}Y $$
#
# Where $ B_0 = C_0 + G_0 + I_0 + X_0  $
# and $  B_1 = 1 - (b - m)(1 - t) $

# %% [markdown]
# #### Using Python, plot the next figure and explain $ Y^e $ and $ DA^e $ represent in

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy

# %%
Y_size = 100
k = 20                
j = 10                
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 33             
j = 5               
Ms = 35000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, i_0, color = "orange")
ax.plot(Y, i, color = "none")
ax.plot(Y, i_1,linestyle='solid', color = "green")
plt.axvline(x=54,  ymin=-100, ymax= 0.55, linestyle = "dotted", color = "black")
plt.axhline(y=3, xmin=-100, xmax= 0.54, linestyle = "dotted", color = "black")  
plt.axhline(y=-100, xmin=-100, xmax= 1, linestyle = "dotted", color = "black")
plt.text(80, 110, "DA = α0 + α1Y", color='black', size = 14)
plt.text(80, 40, "α1 = (b-m)(1-t)", color='black', size = 14)
plt.text(65, -170, "α0 =(C0 +I0 +G0 +X0 −hr)", color='black', size = 14)
plt.text(-20, -5, "DA", color='black', size = 18)
plt.text(-17, 330, "DA", color='black', size = 18)
plt.text(-20, -100, "α0", color='black', size = 18)
plt.text(51, -440, "Y^e", color='black', size = 18)
plt.text(100, -440, "Y", color='black', size = 18)
plt.text(3, -360, "45˚", color='black', size = 18)
plt.show()

# %% [markdown]
# #### What happens if the Marginal Propensity to Consume increases. Explain using intuition, Math, and a Figure.

# %% [markdown]
# - Intuitive explanation:
#
# $b↑$ $→C$ $→DA$ > $Y→$ $Y↑$
#
#
# - Math:
#
#
# $ ΔY={((1-t) Δb)}\frac {((1-(1-t)*(b-m))^2)} >0 $
#
#
# $ ΔDA$=$ Δb(1-t)ΔY $

# %% [markdown]
# If the marginal propensity to consume increases, the consumption increases, therefore the aggregate demand increases so it becomes greater than production, then the production increases.

# %% [markdown]
# #### 2. Find the Equilibrium equation for the Aggregate Income. Please, write all the equations in steps.

# %% [markdown]
# $ Y = DA $
#
# $ Y = (C0 + I0 + G0 + X0 − hr) + (b - m)(1 - t)Y $
#
# $  Y - (b - m)(1 - t)Y = [C0 + I0 + G0 + X0 - hr] $
#
# $ [1 - (b-m)(1-t)]Y = [C0 + I0 + G0 + X0 - hr] $
#
#
# $ Y = (1/[1 - (b-m)(1-t)]) [C0 + I0 + G0 + X0 - hr] $
#
# $ K = (1/[1 - (b-m)(1-t)]) $

# %% [markdown]
# #### Using Python, plot the equilibrium and explain what  $ Y^e $ and $ DA^e $

# %%
Y_size = 100
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 33             
j = 5               
Ms = 35000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 10               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, i_2,linestyle='dashed' )
ax.plot(Y, i_0, color = "green")
ax.plot(Y, i_1,linestyle='solid', color = "blue")
plt.axvline(x=54,  ymin=-100, ymax= 0.55, linestyle = "dotted", color = "black")
plt.axhline(y=3, xmin=-100, xmax= 0.54, linestyle = "dotted", color = "black")  
plt.axhline(y=-100, xmin=-100, xmax= 1, linestyle = "dotted", color = "black")
plt.text(80, 110, "DA = α0 + α1Y", color='black', size = 14)
plt.text(80, 40, "α1 = (b-m)(1-t)", color='black', size = 14)
plt.text(65, -170, "α0 =(C0 +I0 +G0 +X0 −hr)", color='black', size = 14)
plt.text(-20, -5, "DA", color='black', size = 18)
plt.text(-17, 330, "DA", color='black', size = 18)
plt.text(-20, -100, "α0", color='black', size = 18)
plt.text(51, -440, "Y", color='black', size = 18)
plt.text(100, -440, "Y", color='black', size = 18)
plt.text(3, -360, "45˚", color='black', size = 18)
plt.show()

# %% [markdown]
# #### What happens with the endogenous variables if the government increases its spending and at the same time increases taxes by the same magnitude to keep the budget balanced; that is Δ𝑇 = Δ𝐺. Explain using intuition, Math, and a Figure.

# %% [markdown]
# Intuition:
#
# When government spending increases:
#
# $$ G_0\uparrow \rightarrow G\uparrow \rightarrow DA\uparrow \rightarrow DA>Y \rightarrow Y\uparrow$$
#
# When taxes increase:
#
# $$ t\uparrow \rightarrow C\downarrow \rightarrow DA\downarrow \rightarrow DA<Y \rightarrow Y\downarrow$$
#
# Math:
#
# $$ΔY = \frac{1}{1 - b}(-bΔT + ΔG)$$
#
# $$ΔY = \frac{1 - b}{1 - b}ΔG$$
#
# $$ΔY = ΔG$$

# %%
Y_size = 100
k = 20                
j = 10               
Ms = 25000             
P  = 14             
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 33             
j = 5               
Ms = 40000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 10               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, i_2, linestyle='dashed' )
ax.plot(Y, i_0, color = "red")
ax.plot(Y, i_1,linestyle='solid', color = "green")
plt.axvline(x=48,  ymin=-100, ymax= 0.49, linestyle = "dotted", color = "black")
plt.axvline(x=64,  ymin=-100, ymax= 0.642, linestyle = "dotted", color = "black")
plt.axhline(y=27, xmin=-100, xmax= 0.642, linestyle = "dotted", color = "black")  
plt.axhline(y=-80, xmin=-100, xmax= 0.49, linestyle = "dotted", color = "black")
plt.text(80, 110, "DA1 = (α0 + ∆G) + α1Y", color='black', size = 14)
plt.text(80, -40, "DA0 = α0+α1Y", color='black', size = 14)
plt.text(-20, -5, "DA1^e", color='black', size = 18)
plt.text(-17, 330, "DA", color='black', size = 18)
plt.text(-20, -100, "DA", color='black', size = 18)
plt.text(40, -490, "Y", color='black', size = 18)
plt.text(60, -490, "Y1^e", color='black', size = 18)
plt.text(100, -490, "Y", color='black', size = 18)
plt.text(3, -410, "45˚", color='black', size = 18)
plt.show()

# %% [markdown]
# ## 02: IS-LM

# %% [markdown]
# #### Show the derivation of the IS curve from equilibrium Y=DA. Explain using intuition, Math, and a Figure.

# %% [markdown]
# $ Y= C + I + G + X - M $
#
# $ Y = DA $
#
# $ DA = C0 + bY^d + I0 − hr + G0 + X0 - mY^d $
#
# $ DA =(b-m)(1-t)Y + C0 + I0 - hr + G0 + X0 $
#
# $ DA =(C0 + I0 + G0 + X0 - hr)+(b - m)(1 - t)Y $
#
# $ Y = (C0 + I0 + G0 + X0 − hr) + (b - m)(1 - t)Y $
#
# $ Y = Y - (b - m)(1 - t)Y = [C0 + I0 + G0 + X0 - hr] $
#
# $ Y = [1 - (b-m)(1-t)]Y = [C0 + I0 + G0 + X0 - hr]  $
#
# $ Y* = (1/(1-(b-m)(1-t))[C0 + I0 + G0 + X0 - hr] $

# %%
Y_size = 100
k = 20                
j = 10               
Ms = 25000             
P  = 13             
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 33             
j = 5               
Ms = 40000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 10               
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, i_2, linestyle='dashed' )
ax.plot(Y, i_0, color = "green")
ax.plot(Y, i_1, linestyle='solid', color = "yellow")
plt.axvline(x=45.5,  ymin=-100, ymax= 0.47, linestyle = "dotted", color = "black")
plt.axvline(x=65.5,  ymin=-100, ymax= 0.65, linestyle = "dotted", color = "black")
plt.axhline(y=30, xmin=-100, xmax= 0.65, linestyle = "dotted", color = "black")  
plt.axhline(y=-100, xmin=-100, xmax= 0.465, linestyle = "dotted", color = "black")
plt.text(80, -70, "DA(0)", color='black', size = 14)
plt.text(80, 40, "DA(1)", color='black', size = 14)
plt.text(43, -80, "E0", color='black', size = 14)
plt.text(64, 60, "E1", color='black', size = 14)
plt.text(-17, 250, "DA", color='black', size = 18)
plt.text(43, -490, "Y0", color='black', size = 18)
plt.text(64, -490, "Y1", color='black', size = 18)
plt.text(110, -490, "Y", color='black', size = 18)
plt.text(3, -400, "45˚", color='black', size = 18)
plt.show()

# %% [markdown]
# #### Derive the IS curve from the Save-Investment Equilibrium.

# %% [markdown]
# The equality between saving and investment is:
#
# $$S(Y) = I(r)$$
#
# Then we get:
#
# $$(Y^d - C_0 - bY^d) + (T - G_0) + (mY^d - X_0) = I_0 - hr$$
#
# The equation of the IS curve is obtained:
#
# $$[1-(b-m)(1-t)]Y-(C_0+G_0+X_0) = I_0 - hr$$
#
# We obtain an equivalence for the equilibrium function:
#
# $$r = \frac{1}{h}(C_0 + G_0 + I_0 + X_0) - \frac{1-(b-m)*(1-T)}{h}*Y$$
#
# Wich also means:
#
# $$r=\frac{\beta_0}{h}-\frac{\beta_1}{h}Y$$
#
# Where:
#
# $$\beta = C_0 + G_0 + I_0 + X_0$$
#
# and
#
# $$\beta_1 = 1-(b-m)(1-t)$$

# %% [markdown]
# #### Show the derivation of the LM curve from equilibrium $ M^s = M^d $ . Explain using intuition, Math, and a Figure.

# %% [markdown]
# Math:
#
# $M^s$ = $\dfrac{M^s}{P}$ and $M^d = kY - jr$
#
# $\dfrac{M^s}{P}$ = $kY - jr$
#
# $jr$ = $kY$ - $\dfrac{M^s}{P}$
#
# $LM:$ $r$ = - $\dfrac{1}{j}$$\dfrac{M^s}{P}$ + $\dfrac{k}{j}$$Y$

# %%
Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
   

Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

Y_size = 100
c = 45                
b = 0.05               
           
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 2             
h = 1  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)




Y_size = 100
c = 70                
b = 0.05               
           
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 90
X_bar = 2             
h = 1  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Derivation of the Money Market Equilibrium LM Curve", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i, color = "green")
ax.plot(Y, i_2, color = "skyblue")
ax.plot(Y, i_1, linestyle='dotted',color= "blue")
ax.vlines(x=59, ymin=-150, ymax=200,linestyle='solid', colors='black')
ax.hlines(y=18, xmin=-8, xmax=59,linestyle='dotted', colors='black')
ax.hlines(y=-30, xmin=-8, xmax=59,linestyle='dotted', colors='black')
ax.hlines(y=63, xmin=-8, xmax=59,linestyle='dotted', colors='black')
plt.text(95, 5, "C", color='black')
plt.text(95, -45, "B", color='black')
plt.text(95, -95, "A", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()

# %%
Y_size = 100
k = 0.7                
j = 0.8                
Ms = 80                
P  = 2                 

Y = np.arange(Y_size)

# %%
def r_LM(k, j, Ms, P, Y):
    r_LM = -(Ms/P)/j + (k/j)*Y
    return r_LM

r_LM = r_LM(k, j, Ms, P, Y)

# %%
y_max = np.max(r)
                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Derivation of the LM curve from equilibrium $M^s=M^d$", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, r_LM, label = "LM", color="orange")

plt.plot(80.9, 20.5, marker="o", color="black", label = "A'")
plt.plot(96, 34, marker="o", color="black", label = "B'")

plt.axvline(x=80.9,  ymin= 0, ymax= 0.78, linestyle = ":", color = "gray")
plt.axhline(y=20.5, xmin= 0, xmax= 0.78, linestyle = ":", color = "gray")

plt.axvline(x=96,  ymin= 0, ymax= 0.92, linestyle = ":", color = "gray")
plt.axhline(y=34, xmin= 0, xmax= 0.92, linestyle = ":", color = "gray")

plt.text(80, 23, 'A', fontsize = 13, color = 'black')
plt.text(94.8, 36.7, 'B', fontsize = 13, color = 'black')

plt.text(-11, 20.5, '$r_0$', fontsize = 15, color = 'black')
plt.text(-11, 34, '$r_1$', fontsize = 15, color = 'black')

plt.text(80.5, -60, '$Y_0$', fontsize = 15, color = 'black')
plt.text(94, -60, '$Y_1$', fontsize = 15, color = 'black')

plt.show()

# %% [markdown]
# ## 03: DA-OA Model

# %% [markdown]
# #### Find the equilibrium equation of $ Y^e,P^e $ , and $ r^e $ .

# %% [markdown]
# $$\frac{C_0 + I_0+ G_0}{h} - \frac{[1-b(1 - t)]Y}{h} = \frac{kY}{j} - \frac{M_0^s}{P_0 j}$$
#
# $$\frac{C_0 + I_0+ G_0}{h} + \frac{M_0^s}{P_0 j} = \frac{kY}{j} + \frac{[1-b(1 - t)]Y}{h}$$
#
# $$\frac{C_0 + I_0+ G_0}{h} + \frac{M_0^s}{P_0 j} =  Y  (\frac{k}{j} + \frac{1-b(1 - t)}{h}$$
#
# $$\frac{C_0 + I_0+ G_0}{h} + \frac{M_0^s}{P_0 j} = Y  (\frac{kh + [1-b(1 - t)]j}{hj})$$
#
# $$(\frac{C_0 + I_0+ G_0}{h} + \frac{M_0^s}{P_0 j})  (\frac{hj}{kh + [1-b(1 - t)]j}) = Y$$
#
# $$Y = \frac{(C_0 + I_0+ G_0)hj}{h(kh + [1-b(1 - t)]j} +  \frac{M_0^s h}{P_0 kh + [1-b(1 - t)]j}$$
#
# $$Y^e= \frac{(C_0 + I_0+ G_0)j}{(kh + [1-b(1 - t)]j} + \frac{h}{kh + [1-b(1 - t)]j}  \frac{M_0^s}{P_0^s}$$
#
# $$Y^e =\frac{j \beta_0}{kh + j\beta_1} + (\frac{h}{kh + j\beta_1})\frac{M^s_0}{P_0}$$

# %% [markdown]
# IS: $r = \frac{\beta_0}{h} - \frac{\beta_1}{h}Y$
#
# Where:
#
# $\beta_0 = C_0 + I_0 + G_0 + X_0 $
#
# $ \beta_1 = 1 - (b - m) (1 - t)$
#
# LM: $r = -\frac{1}{j}\frac{M^s_0}{P_0} + \frac{k}{j}Y$
#
# $ \frac{\beta_0}{h} - \frac{\beta_1 Y}{h} = \frac{kY}{j} - \frac{M^s_0}{P_0 j} $
#
# $ \frac{\beta_0}{h}-\frac{\beta_1 Y}{h}-\frac{kY}{j}=-\frac{1}{P_0}\frac{M^s_0}{j} $
#
# $ \frac{\beta_0}{h}-\frac{\beta_1 Y}{h}-\frac{kY}{j}\frac{j}{M^s_0}=-\frac{1}{P_0} $
#
# $ \frac{(\beta_0 - \beta_1Y)j - khY}{hj}\frac{j}{M_0^s} = - \frac{1}{P_0} $
#
# $ - P =  \frac{M_0^s h}{j\beta_0 - (j\beta_1 + hk)Y} $
#
# $ P^e = \frac{M^s_0 h}{-j\beta_0 + (j \beta_1 + hk)Y} $

# %% [markdown]
# Then:
#
# $$r^e =\frac{k \beta_0}{kh + j\beta_1} - \frac{\beta_1}{kh + j\beta_1}\frac{M^s_0}{P_0}$$

# %% [markdown]
# #### Graph the Equilibrium in the IS-LM markets and also in the aggregate demand and supply. (In one figure, you have to use the r and Y axis, and in the other one, the P and Y-axis)

# %%
# IS Curve
Y_size = 100 
b = 0.4                 
m = 0.2                 
t = 0.9                  
Co = 20              
Io = 10                  
Go = 50                 
Xo = 2                  
h =  1                 

Y = np.arange(Y_size)

# %%
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
r
# Out:
# array([ 82.  ,  81.02,  80.04,  79.06,  78.08,  77.1 ,  76.12,  75.14,
#         74.16,  73.18,  72.2 ,  71.22,  70.24,  69.26,  68.28,  67.3 ,
#         66.32,  65.34,  64.36,  63.38,  62.4 ,  61.42,  60.44,  59.46,
#         58.48,  57.5 ,  56.52,  55.54,  54.56,  53.58,  52.6 ,  51.62,
#         50.64,  49.66,  48.68,  47.7 ,  46.72,  45.74,  44.76,  43.78,
#         42.8 ,  41.82,  40.84,  39.86,  38.88,  37.9 ,  36.92,  35.94,
#         34.96,  33.98,  33.  ,  32.02,  31.04,  30.06,  29.08,  28.1 ,
#         27.12,  26.14,  25.16,  24.18,  23.2 ,  22.22,  21.24,  20.26,
#         19.28,  18.3 ,  17.32,  16.34,  15.36,  14.38,  13.4 ,  12.42,
#         11.44,  10.46,   9.48,   8.5 ,   7.52,   6.54,   5.56,   4.58,
#          3.6 ,   2.62,   1.64,   0.66,  -0.32,  -1.3 ,  -2.28,  -3.26,
#         -4.24,  -5.22,  -6.2 ,  -7.18,  -8.16,  -9.14, -10.12, -11.1 ,
#        -12.08, -13.06, -14.04, -15.02])

# %%
Y_size = 100

k = 15                
j = 10                
Ms = 9000             
P  = 20         

Y = np.arange(Y_size)

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
i
# Out:
# array([-45. , -43.5, -42. , -40.5, -39. , -37.5, -36. , -34.5, -33. ,
#        -31.5, -30. , -28.5, -27. , -25.5, -24. , -22.5, -21. , -19.5,
#        -18. , -16.5, -15. , -13.5, -12. , -10.5,  -9. ,  -7.5,  -6. ,
#         -4.5,  -3. ,  -1.5,   0. ,   1.5,   3. ,   4.5,   6. ,   7.5,
#          9. ,  10.5,  12. ,  13.5,  15. ,  16.5,  18. ,  19.5,  21. ,
#         22.5,  24. ,  25.5,  27. ,  28.5,  30. ,  31.5,  33. ,  34.5,
#         36. ,  37.5,  39. ,  40.5,  42. ,  43.5,  45. ,  46.5,  48. ,
#         49.5,  51. ,  52.5,  54. ,  55.5,  57. ,  58.5,  60. ,  61.5,
#         63. ,  64.5,  66. ,  67.5,  69. ,  70.5,  72. ,  73.5,  75. ,
#         76.5,  78. ,  79.5,  81. ,  82.5,  84. ,  85.5,  87. ,  88.5,
#         90. ,  91.5,  93. ,  94.5,  96. ,  97.5,  99. , 100.5, 102. ,
#        103.5])

# %%
y_max = np.max(i)

fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Simultaneous equilibrium in money and goods markets", xlabel= r'Y', ylabel= r'r')

ax.plot(Y, r, "k-", label = "IS", color = "green")
ax.plot(Y, i, "b-", label="LM", color = "blue")

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle = ":", color = "black")
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle = ":", color = "black")
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(49,38, 'E', fontsize = 14, color = 'black')

plt.text(99, 99, fontsize=13)
plt.text(99, -11, fontsize=13)
plt.text(48, 80, 'I', fontsize=13)
plt.text(80, 35, 'II', fontsize=13)
plt.text(48, -13, 'III', fontsize=13)
plt.text(20, 35, 'IV', fontsize=13)

ax.legend()
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_16264/2089645230.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_16264/2089645230.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "blue")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_16264/2089645230.py in <module>
#      15 plt.text(49,38, 'E', fontsize = 14, color = 'black')
#      16
# ---> 17 plt.text(99, 99, fontsize=13)
#      18 plt.text(99, -11, fontsize=13)
# ...

# %% [markdown]
# #### What happens with the endogenous variables if $ G $  decreases? Explain using intuition, Math, and a Figure. (In one figure, you have to use the r and Y axis, and in the other one, the P and Y-axis)

# %% [markdown]
# $ ∆Y = [j/kh+jß1]∆G $
# $ ∆r = [k/kh+jß1]∆G $
#
# Intuition:
#
# $$ G\downarrow \rightarrow DA\downarrow \rightarrow DA<Y \rightarrow Y\downarrow$$

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
Y_size = 100
c = 40                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, i_0, linestyle='solid', label="LM_0", color='orange')
ax.plot(Y, i, linestyle='solid', label="IS_0", color='red')
ax.plot(Y, i_2, linestyle='dashed',label="LM_2", color= "blue")
ax.plot(Y, i_1, linestyle='dashed',label="LM_1", color= "green")
ax.vlines(x=55.5, ymin=-100, ymax=82,linestyle='dotted', colors='black')
ax.hlines(y=78, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, 'LM (P0)', color='black')
plt.text(20, 160, "LM'(P1)", color='black')
plt.text(20, 0, "IS'", color='black')
plt.text(20, -40, "IS", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.show()

# %%
Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
Y_size = 100
c = 45                
b = 0.05               
           
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 2             
h = 1  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effect of a decrease in Government Spending", xlabel=r'Y', ylabel=r'P')
ax.plot(Y, i_0,  label="LM_0", color='red')
ax.plot(Y, i, label="IS_2", linestyle = 'dotted')
ax.plot(Y, i_1, linestyle='solid',color= "orange", label="IS_1")
ax.vlines(x=59, ymin=-100, ymax=20,linestyle='dotted', colors='black')
ax.vlines(x=47, ymin=-100, ymax=-6,linestyle='dotted', colors='black')
ax.hlines(y=18, xmin=-8, xmax=60,linestyle='dotted', colors='black')
ax.hlines(y=-7, xmin=-8, xmax=48,linestyle='dotted', colors='black')
plt.text(95, 100, "LM", color='black')
plt.text(95, -45, "IS", color='black')
plt.text(95, -95, "IS'", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.show()

# %% [markdown]
# #### What happens with the endogenous variables if $ M_s^0 $ decreases? Explain using intuition, Math, and a Figure. (In one figure, you have to use the r and Y axis, and in the other one, the P and Y-axis)

# %% [markdown]
# Intuiton:
#
# $ M^s_0\downarrow \rightarrow \frac{M^s}{P}<M^d \rightarrow r\uparrow $
#
# $ r\uparrow \rightarrow I\downarrow \rightarrow AD\downarrow \rightarrow AD<Y\rightarrow Y\downarrow $
#
# $ Y\downarrow \rightarrow (Y-\bar{Y})\downarrow \rightarrow P\downarrow $

# %% [markdown]
# Math:
#
# $ \frac{dY}{dM^s_0} = \frac{-h}{|A|P_0} < 0 $
#
# $ \frac{dr}{dM^s_0} = \frac{1-b(1-t)}{|A|P_0} > 0 $
#
# $ \frac{dP}{dM^s_0} = \frac{-\Theta h}{|A|P_0} < 0 $

# %%
Y_size = 100
k = 20                
j = 10                
Ms = 10000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
             
k = 20                
j = 10               
Ms = 15000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
             
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 30                
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 30            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="OA-DA Model: Effects of a Contractionary Monetary Policy (dM^s0 < 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_2, linestyle='dotted', label="LM_2", color = 'green')
ax.plot(Y, i, label="IS_0", color = 'skyblue')
ax.plot(Y, i_1, linestyle='dashed', color = "blue")
ax.plot(Y, i_0, color = "blue")
ax.vlines(x=55, ymin=-100, ymax=10,linestyle='dotted', colors='black')
ax.hlines(y=35, xmin=-8, xmax=43,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=8, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.vlines(x=48, ymin=-100, ymax=26,linestyle='dotted', colors='black')
ax.vlines(x=42.5, ymin=-100, ymax=31,linestyle='dotted', colors='black')
plt.text(20, 0.5, 'LM (M1, P0)', color='black')
plt.text(20, 80, "IS", color='black')
plt.text(20, -40, "LM (M1, P1)", color='black')
plt.text(20, -70, "LM (Mo, Po)", color='black')
plt.show()

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
Y_size = 100
c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="OA-DA Model: Effects of a Contractionary Monetary Policy", xlabel=r'Y', ylabel=r'P')
ax.plot(Y, i_0,  linestyle='none')
ax.plot(Y, i, linestyle='solid', color = 'skyblue')
ax.plot(Y, i_2, linestyle='dashed', color= "blue")
ax.plot(Y, i_1, linestyle='solid', color = 'red')
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, "DA'", color='black')
plt.text(20, 120, "OA", color='black')
plt.text(20, -40, "DA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()

# %% [markdown]
# ## 04: IS-LM Model with exogenous interest set by the central bank

# %% [markdown]
# #### Find the equilibrium equation of $ Y $ and $ M_s^0 $ .

# %% [markdown]
# $ DA = [C_0 + b(1-t)Y] + I_0 - hr + tY - X_0 - mY $
#
# $ Y^e = [\frac{\beta_1k}{kb\beta+\beta_1}]A_0 - [\frac{kb}{kb\beta+\beta_1}]\bar{B}+[\frac{kb}{kb\beta+\beta_1}]B^{b1}-[\frac{kb}{kb\beta+\beta_1}]P-[\frac{kb\beta_0}{kb\beta+\beta_1}]r_0 $

# %% [markdown]
# For $M^s_0$:
#
# $ M^s = B^{b0} + B^{b1} $
#
# $ M^d = P + 𝛼Y − 𝛼_0𝑟_0 − 𝛼_1𝑟_1 $
#
# In equilibrium, $M^s$ must be equal to $M^d$
#
# $ M^s = M^d $
#
# $ B^{b0} + B{b1} = P + 𝛼Y − 𝛼_0𝑟_0 − 𝛼_1𝑟_1 $
#
# Then we get the equilibrium line in the money market (LM):
#
# $ r_1 = \frac{-[B^{b0} + B^{b1}-P +𝛼_0r_0]}{𝛼_1}+\frac{𝛼}{𝛼_1}Y $

# %% [markdown]
# #### Graph the Equilibrium in the IS-LM markets and draw a horizontal line for the exogenous value of $ r $.

# %%
Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="IS-LM Model with exogenous interest set by the central bank", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", label="LM_0", color= "green")
ax.plot(Y, i, "r-",label="IS_0", color = "blue")
ax.vlines(x=47, ymin=-120, ymax=-6,linestyle='dotted', colors='black')
ax.hlines(y=-7, xmin=-8, xmax=100,linestyle='solid', colors='black')
plt.text(41, 7, 'E=( Y0, r0 )', color='black')  
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_16264/3373711671.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "b-", label="LM_0", color= "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_16264/3373711671.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",label="IS_0", color = "blue")

# %% [markdown]
# #### What happens with the endogenous variables if  $ G $ decreases? Explain using intuition, Math, and a Figure.

# %% [markdown]
# In DA:
#
# $ G\downarrow \rightarrow DA\downarrow \rightarrow DA<Y \rightarrow Y\downarrow $
#
# $ Y\downarrow \rightarrow M^d\downarrow $
#
# In OA:
#
# $ Y\downarrow \rightarrow P\downarrow $
#
# $ Y\downarrow \rightarrow (Y-\bar{Y})\downarrow \rightarrow P\downarrow $
#
# So
#
# $ G\downarrow \rightarrow r (long-term)\downarrow \rightarrow P \downarrow \rightarrow Y\downarrow $

# %% [markdown]
# Math:
#
# $$𝒅𝑮𝟎 < 𝟎$$
#
# $$Y^e = [\frac{\beta_1k}{kb\beta+\beta_1}]A_0 - [\frac{kb}{kb\beta+\beta_1}]\bar{B}+[\frac{kb}{kb\beta+\beta_1}]B^{b1}-[\frac{kb}{kb\beta+\beta_1}]P-[\frac{kb\beta_0}{kb\beta+\beta_1}]r_0 < 0$$
#
#
# $$r_1 = \frac{-[B^{b0} + B^{b1}-P +𝛼_0r_0]}{𝛼_1}+\frac{𝛼}{𝛼_1}Y < 0$$

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 40                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, i_0,  linestyle='dashed', label="LM_0")
ax.plot(Y, i, linestyle='none', label="IS_0")
ax.plot(Y, i_2, linestyle='solid', color= "blue")
ax.plot(Y, i_1, linestyle='solid', color= "red")
ax.vlines(x=48, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=63, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=45, xmin=-8, xmax=56,linestyle='dotted', colors='black')
ax.vlines(x=57, ymin=-100, ymax=48,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 0, "LM'(P1)", color='black')
plt.text(20, -40, "LM (P0)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()

# %% [markdown]
# #### What happens with the endogenous variables if  $ r $ decreases? Explain using intuition, Math, and a Figure.

# %% [markdown]
# MATH:
# $ ∆Y = [j/kh+jß1]∆G $
# $ ∆r = [k/kh+jß1]∆G $

# %%
Y_size = 100
           
k = 20                
j = 8              
Ms = 1000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 20              
j = 8               
Ms = 8000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 40                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, i, linestyle='solid', label="IS_0", color="blue")
ax.plot(Y, i_2, linestyle='none', color= "orange")
ax.plot(Y, i_1, linestyle='dashed', color= "green")
ax.vlines(x=50, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=59, xmin=-8, xmax=100,linestyle='dashed', colors='black')
ax.hlines(y=85, xmin=-8, xmax=100,linestyle='solid', colors='green')
ax.vlines(x=35.5, ymin=-100, ymax=84,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 25, "LM(M0)", color='black')
plt.text(20, -30, "LM (M1)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
