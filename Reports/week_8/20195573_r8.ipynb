# %% [markdown]
# Yarim Kamila Gamarra Dávila - 20195573

# %% [markdown]
# I. Report of the article: “La macroeconomía de la cuarentena: un modelo de dos sectores”
#
# This article has the objective to present a macroeconomic model to simulate the effects of the quarantine in the level of production and prices in two different economic sectors and the effects of the end of it for the Peruvian economy. To achieve this, the author used three subsystems of the model: the short term, the stationary equilibrium and the transition towards the stationary equilibrium to analyze. The authors concluded that both sectors were adversely affected, one directly and one indirectly, but the one directly affected suffered the most. In addition, the authors established that the credit policy applied in 2020-2021 avoided a massive bankruptcy of companies and made possible a fast recovery of the Peruvian economy.
#
# First, one of the main strengths in this article is its structure. In the first part, the authors decided to provide a theoretical base to land it, in the second part, in the Peruvian reality. In the first part, the authors offered a detailed explanation about the equations, graphics, and macroeconomic theory. I believe this is relevant because the authors did not assume the macroeconomic knowledge of the readers and provided a comprehensive theoretical explanation of the changes in the economy during this period. Moreover, the second part of the article, the authors used real data to show the application of these theories. I consider this an important advantage because it helps to have a clear image of what happened during this recent tragic episode and how it affected our economy. On the other hand, I consider important that the authors considered two different economic sectors to make this analysis. This because the quarantine did not affected everyone the same way and it is important to make the distinctions in each sector, so the analysis become more precise, realistic and relevant. Lastly, the authors included in the conclusion some other directions of this analysis for future investigations, which is important because it offers ideas to keep investigating this recent episode in our history.
#
# Second, the fact that this article tries to explain the economic consequences of such a recent phenome like the pandemic is innovative and impressive, but it can also have some important disadvantages. First, the authors could only analyze the immediate effects, but they can not include an analysis of the long term, which I consider relevant to see the real magnitude of the effects on the economy. Second, there are not much other investigations about this topic, which can affect the confidence in this article because of the lack of other opinions, positions and discoveries. On the other hand, the author only focused on the economic processes, but I consider it would be relevant to consider other factors as well. As we know, the pandemic had not only economic consequences, but also, social, political and environmental. I believe that other factors like a decrease in human productivity, the effects on mental and physical health, and others, could have had an impact in the economy. Moreover, more politics that accompanied the quarantine, like the bonuses the government gave, could also have an impact in the economy and were not considered. In this way, it would have been relevant if the author could take into consideration other variables to explain the decrease in the Peruvian economy.
#
# Finally, despite the weaknesses mentioned before, I consider this article provides a huge contribution to the construction of data about a new topic that had tremendous effects around the world. In Peru, specifically, this article helps to have a general understanding of the economic crisis we suffered and the policies applied to have a successful recovery. Moreover, the equations, graphics and the macroeconomic model the author provided are relevant because they can be used as a base for different and new investigations. In this way, I believe a next step to follow is to analyze other social factors to see the impact they had in the economic crisis. Moreover, it would be interesting to include the different politics the government used during this period to see the consequences they had for out economy. It would also be important to, in some years, analyze if there are still repercussions of the quarantine in our economy to see the real magnitude of this crisis.

# %%
II. Code Section

# %% [markdown]
# 2.1 The equilibrium in the IS - LM model
#
# IS:
#
# \begin{align}
#     \ r &= \frac {β_0}{h}\ - \frac {β_1}{h}Y\         (1)
# \end{align}
#
#
# LM:
#
# \begin{align}
#     \ r &= - \frac {1}{j}\ \frac {M^s _ 0}{P_0}\ + \frac {K}{j} Y\  (2)
# \end{align}
#
#
# IS = LM:
#
# \begin{align}
#    - \frac {1}{j}\ \frac {M^s _ 0}{P_0}\ + \frac {K}{j} Y \ &=\ \frac {β_0}{h}\ - \frac {β_1}{h}Y\ (3)
# \end{align}
#
#
# Equilibrium income level:
#
# \begin{align}
#    \ Y^e &= -  \frac {j β_0}{kh + j β_1} Y \ + \frac {h}{kh + j β_1}\ \frac {M^s _ 0}{P_0}\  (4)
# \end{align}
#
#
# Equilibrium interest rate:
#
# \begin{align}
#    \ r^e &=  \frac {k β_0}{kh + j β_1} Y \ - \frac {β_1}{kh + j β_1}\ \frac {M^s _ 0}{P_0}\  (5)
# \end{align}

# %% [markdown]
# 2.2 Equilibirum in the IS-LM model

# %%
import numpy as np               
import matplotlib.pyplot as plt  


Y_size = 100          
k = 20               
j = 10                
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


Y_size = 100
c = 20                 
b = 0.01                
m = 0.9            
T = 1                 
I_bar = 20             
G_bar = 55              
X_bar = 2             
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS
def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Simultaneous equilibrium in the goods and money markets", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "g-", label="LM")
ax.plot(Y, i, "y-",label="IS")

plt.axvline(x=51,  ymin= 0, ymax= 0.52, linestyle = ":", color = "black") 
plt.axhline(y=1, xmin= 0, xmax= 0.52, linestyle = ":", color = "black")   
plt.plot(51,1, marker="o", color="black")
plt.text(50.1, 5, 'E', fontsize=12, color='black')

ax.legend()
plt.show()

# %% [markdown]
# 2.3 Increase in Government Spending

# %%
import numpy as np               
import matplotlib.pyplot as plt  

Y_size = 100          
k = 20                
j = 10               
Ms = 20000            
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100
c = 20                 
b = 0.01                
m = 0.9            
T = 1                  
I_bar = 20             
G_bar = 55              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS
def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS
i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

Y_size = 100
c = 20                 
b = 0.01                
m = 0.9            
T = 1                  
I_bar = 20             
G_bar = 75              
X_bar = 2              
h = 1
def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Increase in government spending", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "g-", label="LM_0")
ax.plot(Y, i, "y-",label="IS_0")
ax.plot(Y, i_1, "y-",linestyle='dotted',label="IS_1")

plt.axvline(x=51,  ymin= 0, ymax= 0.47, linestyle = ":", color = "black") 
plt.axhline(y=1, xmin= 0, xmax= 0.52, linestyle = ":", color = "black") 
plt.plot(51, 1, marker="o", color="black", label = "Eo")
plt.text(49,5, 'Eo', fontsize = 14, color = 'black')

plt.axvline(x=56,  ymin= 0, ymax= 0.52, linestyle = ":", color = "black") 
plt.axhline(y=12, xmin= 0, xmax= 0.55, linestyle = ":", color = "black") 

plt.plot(56, 12, marker="o", color="red", label = "Eg")
plt.text(54,17, 'Eg', fontsize = 14, color = 'red')

plt.text(77, -45, '∆Go', fontsize=12, color='black')
plt.text(79, -50, '→', fontsize=15, color='black')


ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/376859410.py:61: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "y-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "y-",linestyle='dotted',label="IS_1")

# %% [markdown]
# * Intuition:
#
# \begin{align}
#     G_0↑→ DA↑→ DA>Y→ Y↑
# \end{align}
#
# \begin{align}
#    Y↑→ M^d↑→ M^d>M^o→ r↑
# \end{align}
#
# First, in the goods market, the increase in the government spending causes an increase in the aggregate demand. In this way, the aggregate demand will be greater than the production level. So, to return to equilibrium, the production level has to increase.
#
# Second, in the money market, an increase in the goverment spendig causes and increase in the production level. This makes a greater demand for money than the money supply. In this way, to return to the equilibrium, the interest rate has to increase.
#
# In conclussion, an increase in the government spending increases the PBI but, because of the raise in the interest rate, the investemnt will decrease.
#
# * Math
#
# \begin{align}
#    \ ΔY^e &=  \frac {j}{kh + j β_1}  \ ΔG_o> 0\
# \end{align}
#
#
# \begin{align}
#    \ Δr^e &=  \frac {k}{kh + j β_1}\  \ ΔG_o> 0\
# \end{align}
#
#
#                     So:
#
# \begin{align}
#    \ ΔY^e &> 0
# \end{align}
#
# \begin{align}
#    \ Δr^e &> 0
# \end{align}

# %% [markdown]
# 2.4 Increase in quantity of money

# %%
import numpy as np              
import matplotlib.pyplot as plt  

Y_size = 100
k = 20                
j = 10                
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


Y_size = 100
             
k = 20                
j = 10               
Ms = 30000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100
c = 20                
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 55              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Increase in the quantity of money", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "g-", label="LM_0")
ax.plot(Y, i, "y-",label="IS_0")
ax.plot(Y, i_1, "y-",linestyle='dashed',label="LM_1", color = "green")

plt.axvline(x=51,  ymin= 0, ymax= 0.60, linestyle = ":", color = "black")
plt.axhline(y=1, xmin= 0, xmax= 0.52, linestyle = ":", color = "black")  

plt.axvline(x=63.7,  ymin= 0, ymax= 0.51, linestyle = ":", color = "black")
plt.axhline(y=-23, xmin= 0, xmax= 0.63, linestyle = ":", color = "black")   

plt.plot(51, 1, marker="o", color="black", label = "Eo")
plt.text(49,5, 'Eo', fontsize = 14, color = 'black')

plt.plot(63.5, -21, marker="o", color="red", label = "E_Ms")
plt.text(61, -15, 'E_Ms', fontsize = 14, color = 'red')

plt.text(68, 15, '∆Ms', fontsize=12, color='black')
plt.text(69, 10, '→', fontsize=15, color='black')


ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/1361179090.py:59: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "y-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "y-",linestyle='dashed',label="LM_1", color = "green")
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/1361179090.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "y-" (-> color='y'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "y-",linestyle='dashed',label="LM_1", color = "green")

# %% [markdown]
# * Intuition:
#
# \begin{align}
#    M^o↑→ M^o>M^d→r↓
# \end{align}
#
# \begin{align}
#    r↓→ I_o↑→ DA↑→ DA>Y→ Y↑
# \end{align}
#
# First,in the money market, the increase un the supply of money makes the money supply to be grater than the money demand. So, to return to the equilibrium, the interest rate has to decrease.
#
# Second, in the good money, the decrease of the interest rate will increase the investment. So, the DA will increase and will become greater than the production level. In this way, the level of production will increase to  return to equilibrium.
#
# In conclussion, an increase in the money supply will decrease the interest rate, which increases the investment and also the GDP
#
# * Math
#
#
# \begin{align}
#    \ ΔY^e &=  \frac {h}{kh + j β_1} \frac {1}{P_0}
# \end{align}
#
# \begin{align}
#    ΔM^S_0 &> 0
# \end{align}
#
# \begin{align}
#    \ Δr^e &=  \frac {β_1}{kh + j β_1} \frac {1}{P_0}
# \end{align}
#
# \begin{align}
#    ΔM^S_0 &< 0
# \end{align}
#
#                      So:
#
# \begin{align}
#    \ ΔY &> 0
# \end{align}
#
# \begin{align}
#    \ Δr &< 0
# \end{align}

# %% [markdown]
# 2.5 Effects of an expansive monetary policy and a restrictive fiscal policy

# %%
import numpy as np               
import matplotlib.pyplot as plt  


Y_size = 100             
k = 20                
j = 10                
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


Y_size = 100
k = 20                
j = 10                
Ms = 30000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)


Y_size = 100
c = 20                 
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 20             
G_bar = 55             
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  

def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS
i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

Y_size = 100
c = 20                
b = 0.01                
m = 0.9            
T = 1                 
I_bar = 20             
G_bar = 6.5              
X_bar = 2             
h = 1                  
Y = np.arange(Y_size) 



def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i_2 = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an expansive monetary policy and a restrictive fiscal policy", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "g-", label="LM_0")
ax.plot(Y, i, "y-",label="IS_0")
ax.plot(Y, i_1, "g-",linestyle='dashed',label="LM_1", color='green')
ax.plot(Y, i_2, "y-",linestyle='dashed',label="IS_1", color='yellow')


plt.axvline(x=51,  ymin= 0, ymax= 0.60, linestyle = ":", color = "black") 
plt.axhline(y=1, xmin= 0, xmax= 0.52, linestyle = ":", color = "black")   
plt.axhline(y=-47, xmin= 0, xmax= 0.52, linestyle = ":", color = "black")   

plt.plot(51, 0, marker="o", color="black", label = "Eo")
plt.text(49,5, 'Eo', fontsize = 14, color = 'black')

plt.plot(51, -48, marker="o", color="red", label = "E_1")
plt.text(49, -43, 'E_1', fontsize = 14, color = 'red')

plt.text(65, 0, '→', fontsize=15, color='black')
plt.text(65, -48, '←', fontsize=15, color='black')


ax.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/1772384555.py:81: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "g-",linestyle='dashed',label="LM_1", color='green')
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/1772384555.py:81: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g-" (-> color='g'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "g-",linestyle='dashed',label="LM_1", color='green')
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/1772384555.py:82: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "y-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "y-",linestyle='dashed',label="IS_1", color='yellow')
# ...

# %% [markdown]
# * Intuition
#
# \begin{align}
#    M^o↑→ M^o>M^d→ r↓
# \end{align}
#
# \begin{align}
#    r↓→ I_o↑→ DA↑→ DA>Y→ Y↑
# \end{align}
#
# \begin{align}
#     G_0↓→ DA↓→ DA<Y→ Y↓
# \end{align}
#
# \begin{align}
#    Y↓→ M^d↓→ M^d<M^o→ r↓
# \end{align}
#
# First, the expansionary monetary policy will cause an increase un the money supply. In this way, this will be greater than the demand, so, the interes rate has to decrease in oroder to return to equilibrium. In addition, the decrease of the interest rate cases an increase in the investment and aggregated demand, which now will be greater than the production level. Int his way, the production level has to increase to return to equilibrium
#
# Second, a restrictive policy will decrease the government spending. This will decrease the DA, which will be lower than the production level, so the production level will have to decrease. In addition, this decrease in the production level will decrease the money demand, which become lower than the money supply, and the interest rate will have to decrease.
#
# In conclussion, both policys cause a decrease in the interest rate. However, the production level rises wwith the expansionary monetary policy but decreases with the restrictive policy. In this way, we can see in the graphic that the production level will remain constan as the interest rate will be lower.
#
# * Math
#
# Monetary Policy:
#
# \begin{align}
#    \ ∆Y^e &= \frac {h}{kh + j β_1} \ \frac {1}{P_0}\ ∆M^s_0 >0
# \end{align}
#
# \begin{align}
#    \ ∆r^e &= -\frac {B_1}{kh + j β_1} \ \frac {1}{P_0}\ ∆M^s_0 <0
# \end{align}
#
# Fiscal Policy:
#
# \begin{align}
#    \ ∆Y^e &= \frac {j}{kh + j β_1} \ ∆G_0 < 0
# \end{align}
#
# \begin{align}
#    \ ∆r^e &= \frac {k}{kh + j β_1} \ ∆G_0 < 0
# \end{align}

# %% [markdown]
# 2.6 Reduction in Tax Rate

# %%
import numpy as np               
import matplotlib.pyplot as plt  

Y_size = 100
c = 20                 
b = 0.20                
m = 0.15            
T = 1                  
I_bar = 10             
G_bar = 8             
X_bar = 2              
h = 5                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS
def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS
i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


Y_size = 100
c = 20                 
b = 0.21                
m = 0.35
T = 1.05                  
I_bar = 10            
G_bar = 8             
X_bar = 2             
h = 5  
def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS
def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS
i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


Y_size = 100
             
k = 18               
j = 40                
Ms = 1000             
P  = 38                
# Arrays
Y = np.arange(Y_size) 
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)



y_max = np.max(i)
x_max = Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, 0)
v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Tax Rate Reduction", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i, "k-",Label="IS_1", linestyle='dashed', color = "orange")
ax.plot(Y, i_1, "r-",Label="IS_0", color = "orange")
ax.plot(Y, i_0, "r-",Label="LM_0", color = "green")

plt.axvline(x=12.8,  ymin= 0, ymax= 0.636, linestyle = ":", color = "black") 
plt.axhline(y=5.08, xmin= 0, xmax= 0.36, linestyle = ":", color = "black")   

plt.axvline(x=13.6,  ymin= 0, ymax= 0.68, linestyle = ":", color = "black") 
plt.axhline(y=5.4, xmin= 0, xmax= 0.39, linestyle = ":", color = "black")   

plt.plot(12.8, 5.1, marker="o", color="black", label = "Eo")
plt.text(12.1, 5.3, 'Eo', fontsize = 14, color = 'black')

plt.plot(13.6, 5.4, marker="o", color="red", label = "E_t")
plt.text(13.2,5.6, 'E_t', fontsize = 14, color = 'red')

plt.text(29.5, 1.7 , '∆t', fontsize=12, color='black')
plt.text(30, 1.5, '→', fontsize=15, color='grey')


plt.axis(v) 
ax.legend()        
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/3965335165.py:61: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "k-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "k-",Label="IS_1", linestyle='dashed', color = "orange")
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/3965335165.py:61: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, i, "k-",Label="IS_1", linestyle='dashed', color = "orange")
# C:\Users\HP\AppData\Local\Temp/ipykernel_22632/3965335165.py:61: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.plot(Y, i, "k-",Label="IS_1", linestyle='dashed', color = "orange")
# ...

# %% [markdown]
# * Intuition
#
# \begin{align}
#     t↓→ Y^d↑→ M↑→(X-M)↓→ DA↓→ DA<Y→ Y↓
# \end{align}
#
# \begin{align}
#    t↓→ Y^d↑→ C^o↑→ DA↑→ DA>Y→ Y↑
# \end{align}
#
# \begin{align}
#    Y↑→ M^d↑→ M^d>M^o→ r↑
# \end{align}
