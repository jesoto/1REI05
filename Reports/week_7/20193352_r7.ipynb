# %% [markdown]
# # Report 7

# %% [markdown]
# Name: María Fernanda Carrasco Sebastian

# %% [raw]
# Code: 20193352

# %% [markdown]
# ## Report section

# %% [markdown]
# Martinelli and Vega's research seeks to explain how Peru's experience of chronic inflation in the 1970s and 1980s manages to explain the monetization of debt within a regime of fiscal dominance. In this sense, the authors explain that hyperinflation occurs when the ability to accumulate more debt vanishes and when the authorities of the time get involved in an unproductive policy of price control and promotion of easy credit. Such fiscal difficulties were experienced by the country prior to stabilization. Likewise, it is exposed that with the experience I learned, the credibility of the change of political regime in the 90s was characterized by public opinion because this allowed the authors to have the necessary incentives to face the consequences of the hyper-stagflation of 1987- 1990. To make progress on this question, the authors use a monetarist approach, that is, they focus on the importance of institutions such as the BCRP and the little state intervention. From there comes his important contribution to the history of Peru.
#
# Thus, one of the strengths of this document is that it provides a historical interpretation of events from the perspective of a monetarist approach to better understand this chronic inflation. In addition, another important point of this document is that it is relevant that
# The story is illustrated with calculations using the government's budget constraint. The important thing about the budget constraint is that it is transparent but also agnostic about the theory. But in the end, it is always the author's task to interpret the story. Another important factor of the work is that it is based on quantitative analysis, presents data and two measurement exercises to better understand the effect of this inflation. It also presents a recipe or "solution" about what should be done in the future with respect to previous experiences. In this case, the prescription is given to the Fujimori government, a period in which the stabilizing stage took place. It is shown that previously, former President García had been wrong with theories that have already proven to be incorrect. In fact, in Carbonetto's book, very influential in the Garcia regime, one can even find an IS-LM diagram where the IS curve has a negatively sloping part. This is a reflection of the beliefs of that time: that a monetary stimulus could increase production without inflation.
#
#
# Faced with these ideas, various weaknesses are presented in the work. First of all, Martinelli and Vega interpret accounting in a way that matches the most common narrative of the time, but the story proved to be more complex than that. On the other hand, something that is not found in the calculations of seigniorage income in the chapter is the role of public banks. In fact, in one of the figures, a large increase in central bank credit to state banks is observed. This expansion corresponds to an increase in the monetary base, but the effect on the monetary aggregate, coming from the creation of cheap deposits and credits by the commercial banks owned by the government, could have been much more important. Similarly, the government's budget constraint does not say enough about whether or not it is easy to reduce the deficit. Standard monetary-fiscal theories assume that it is, but I think the Peruvian case study reveals that it is not. I believe that the García government quickly learned its lesson. If you look at the path of revenue and spending: In the period between 1987 and 1989, the government was striving to reduce its deficits by cutting spending. Finally, it can be argued that the driver of the fiscal deficits was not the poor performance of state enterprises, but rather a failed macroeconomic capital investment program at the national level.
#
# Nonetheless, although it can be argued that Peru has learned its lesson the hard way and has achieved macroeconomic stability. It would be ideal to ask ourselves what were the factors that influenced this change. In this sense, according to an article published in 2021 by the same author entitled 'Determinants of the inflation gap: The case of Peru, this challenge was to increase microeconomic efficiency and reduce corruption. That is, through institutional change.

# %% [markdown]
# ## Code section

# %% [markdown]
# Instruction: Using Python you have to replicate the next figures from this document. You also have to comment why the IS curce moves in each case

# %%
import numpy as np               
import matplotlib.pyplot as plt

# %%
"2|DEFINE PARAMETERS AND ARRAYS of IS_0"
# Parameters

Y_size = 100 
b = 0.4                 #propensión marginal a consumir
m = 0.2                 #propensión a importar
t = 0.3                   #tasa impositiva
Co = 20                 #consumo autónomo
Io = 10                  #inversión autónoma
Go = 8                  #gasto gobierno 
Xo = 2                  #exportación 
h =  5                  #constante de decisión a invertir

Y = np.arange(Y_size)

# %%
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %% [markdown]
# ### 2.1 Effects of increased government spending

# %%
Go = 15
def r_IS_G(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_G(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_G = r_IS_G(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="IS SCHEDULE", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, r, "k-",  scalex = t, scaley = t, label ='IS')
ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, linestyle='dotted', color = "purple", label = 'IS_G')  
ax.legend()
plt.show()
# Out:
# /var/folders/r9/bj8wjj597ndb8jd0zyzwlsn40000gn/T/ipykernel_12294/3808171445.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, linestyle='dotted', color = "purple", label = 'IS_G')
# /var/folders/r9/bj8wjj597ndb8jd0zyzwlsn40000gn/T/ipykernel_12294/3808171445.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, linestyle='dotted', color = "purple", label = 'IS_G')

# %% [markdown]
# As shown in the graph, IS SCHEDULE, the curve moves to the right (expands). This shows an effect on the intercept due to the increase in government spending on aggregate demand. In this sense, it is understood that the effect of this increase presented influences the aggregate demand for goods, which in essence, causes an excess of it. Then, the aggregate demand becomes higher than the equilibrium product.

# %% [markdown]
# ### 2.2 Effects of an increase in the tax rate

# %%
"2|DEFINE PARAMETERS AND ARRAYS"
import numpy as np               
import matplotlib.pyplot as plt  
Y_size = 100
c = 20                 
b = 0.20                
m = 0.15            
T = 1                  
I_bar = 10             
G_bar = 8             
X_bar = 2              
h = 5                  
Y = np.arange(Y_size)

# %%
"3|DEFINE AND POPULATE THE IS-SCHEDULE"
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

Y_size = 100
c = 20                 # Autonomous consumption
b = 0.21                # Marginal propensity to consume
             # Autonomous imports
m = 0.35            # Marginal propensity to import
T = 1.05                  # Taxes
I_bar = 10             # Investment intercept (when i = 0)
G_bar = 8              # Government spending
X_bar = 2              # Exports (given)
h = 5  


def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

"4|PLOT THE IS-SCHEDULE"
y_max = np.max(i)
x_max = Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, 0)

v = [0, x_max, 0, y_max]                        # Set the axes range
fig, ax = plt.subplots(figsize=(10, 8))

ax.set(title="Effects of an increase in the tax rate", xlabel=r'y', ylabel=r'r')
ax.plot(Y, i, "k-",label="IS_0")
ax.plot(Y, i_1, "r-",color="blue",linestyle='dashed', label="IS_1")
plt.text(28, 2, '∆t', fontsize=20, color='black')
plt.text(28, 1.7, '←', fontsize=25, color='black')
plt.axis(v)                 
ax.legend()
plt.show()
# Out:
# /var/folders/r9/bj8wjj597ndb8jd0zyzwlsn40000gn/T/ipykernel_12294/3214934176.py:44: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",color="blue",linestyle='dashed', label="IS_1")
# /var/folders/r9/bj8wjj597ndb8jd0zyzwlsn40000gn/T/ipykernel_12294/3214934176.py:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",color="blue",linestyle='dashed', label="IS_1")

# %% [markdown]
# Here we can see a change in the slope of the curve. In this case, the curve shifts to the left (contracts), because the increase in the tax rate.

# %% [markdown]
# ### 2.3 Effects on an increase in PMgC

# %%
import numpy as np               # Package for scientific computing with Python
import matplotlib.pyplot as plt  # Matplotlib is a 2D plotting library

# Parameters
Y_size = 100
c = 20                 # Autonomous consumption
b = 0.20                # Marginal propensity to consume
             # Autonomous imports
m = 0.2            # Marginal propensity to import
T = 1                  # Taxes
I_bar = 10             # Investment intercept (when i = 0)
G_bar = 8              # Government spending
X_bar = 2              # Exports (given)
h = 5                  # Investment slope wrt to i
# Arrays
Y = np.arange(Y_size)  # Array values of Y

# %%
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#--------------------------------------------------------------
Y_size = 100
c = 20                 # Autonomous consumption
b = 0.35                # Marginal propensity to consume
             # Autonomous imports
m = 0.2            # Marginal propensity to import
T = 1                  # Taxes
I_bar = 10             # Investment intercept (when i = 0)
G_bar = 8              # Government spending
X_bar = 2              # Exports (given)
h = 5  



def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

"4|PLOT THE IS-SCHEDULE"
y_max = np.max(i)
x_max = Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, 0)

v = [0, x_max, 0, y_max]                        # Set the axes range
fig, ax = plt.subplots(figsize=(14, 12))
ax.set(title="Effects of Increased Marginal Propensity to Consume", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i, "k-", label="IS_0")
ax.plot(Y, i_1, "r-",color= "pink", linestyle='dashed', label="IS_1")

plt.axis(v)         
ax.legend () 
plt.text(38, 0.8, '∆b', fontsize=20, color='black')
plt.text(38, 0.65, '→', fontsize=25, color='black')
plt.show()
# Out:
# /var/folders/r9/bj8wjj597ndb8jd0zyzwlsn40000gn/T/ipykernel_12294/2590302389.py:43: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",color= "pink", linestyle='dashed', label="IS_1")
# /var/folders/r9/bj8wjj597ndb8jd0zyzwlsn40000gn/T/ipykernel_12294/2590302389.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",color= "pink", linestyle='dashed', label="IS_1")

# %% [markdown]
# Here we can see that if the marginal propensity to import increases, this causes the curve to expand. It is caused by a decrease in the slope of the IS curve.

# %% [markdown]
# ### 3. Use again the tutorial to derive mathematically and plot the LM-Curve. You should also must-read pages 83-90 to see how to derive equations.

# %% [markdown]
# ### 3.1 Plot the equilibrium in the Monetary Market

# %%
Y_size = 100
Y   = np.arange(Y_size)     # Array values of Y
# IS Parameters
a = 100                     # Autonomous consumption
b = 0.2                     # Marginal propensity to consume
alpha = 5                   # Autonomous imports
beta  = 0.15                # Marginal propensity to import
T = 1                       # Taxes
I = 10                      # Investment intercept (when i = 0)
G = 20                      # Government spending
X = 5                       # Exports (given)
d = 2                       # Investment slope wrt to i
# LM Parameters
c1 = 2500                   # Precautionary money demand
c2 = 0.75                   # Transaction money demand
c3 = 5                      # Speculation money demand
Ms = 23500                  # Nominal money supply
P  = 10                     # Price level

def i_IS(a, alpha, b, beta, T, I, G, X, d, Y):
    i_IS = ((a-alpha)-(b-beta)*T + I + G + X - (1-b+beta)*Y)/d
    return i_IS

def i_LM(c1, c2, c3, Ms, P, Y):
    i_LM = (c1 - Ms/P)/c3 + c2/c3*Y
    return i_LM

iIS = i_IS(a, alpha, b, beta, T, I, G, X, d, Y)
iLM = i_LM(c1, c2, c3, Ms, P, Y)

Y_star1 = ((a-alpha) - (b-beta)*T + I + G + X)/d
Y_star2 = (1/c3) * (c1 - Ms/P)
Y_star3 = (1 - b + beta)/d + (c2/c3)
Y_star  = (Y_star1 - Y_star2)/Y_star3

i_star1 = (1/c3)*(c1 - Ms/P)
i_star2 = (c2/c3)*Y_star
i_star  = i_star1 + i_star2

y_max = np.max(iIS)
v = [0, Y_size, 0, y_max]                      # Set the axes range
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Equilibrium in the Monetary Market", xlabel=r'M^s/P',ylabel= r'r')
ax.plot(Y, iIS, "b-")  
plt.plot(Y_star, i_star, 'ko')                # Equilibrium point
plt.axvline(x=Y_star, ls='-', color='yellow')
plt.axis(v)                                   
plt.show()

# %% [markdown]
# ### 3.2  Plot the LM curve

# %%
Y_size = 100
             
k = 10                # Transaction money demand
j = 10                # Speculation money demand
Ms = 20000             # Nominal money supply
P  = 20                # Price level
# Arrays
Y = np.arange(Y_size)  # Array values of Y

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

y_max = np.max(i)

v = [0, Y_size, 0, y_max]                       # Set the axes range
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="LM curve in the Monetary Market", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", label = "LM_0")
plt.show()
