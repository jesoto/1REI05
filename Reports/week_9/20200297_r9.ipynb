# %% [markdown]
# ### Report 9
# #### Name: Alexandra Gonzalez
# #### Code: 20200297

# %% [markdown]
# #### Report

# %% [markdown]
# The text talks about aggregate demand and supply in the presence of unconventional monetary policies. Its central objective is to effectively model an unconventional monetary policy by extending the standard closed economy aggregate demand and supply model to incorporate the monetary policy innovations applied after the 2008 crisis. Under these criteria, the author uses models ancient economics, thus demonstrating their usefulness in a modern society, arguing in this way that they remain relevant despite the development of modern methods that are widely used today. It was mentioned that the study focuses on the policies adopted as a consequence of the 2008 crisis. This generates the adoption of two unconventional policy instruments, which were the announcement about the future path of the short-term interest rate and the intervention ( purchase) directly in the long-term bond market (essential component of quantitative easing).
#
# The article develops in an orderly manner the analysis of the unconventional policies given after the crisis, demonstrating through formulas and graphs the impact and characteristics of this complex process. Similarly, the fact that it uses an old model and highlights its usefulness is quite useful, allowing it to be understood by theorists who have previously worked with these models. In addition to applying it in a crisis that affected the international scene, reaffirming that it is still a tool capable of explaining a global situation. On the other hand, another advantage of this article is that it uses the hypothesis of rational expectations, since based on this it takes into account the relevance of economic agents and their expectations about the future after a crisis, taking it into account within the model development. In turn, with this hypothesis it efficiently uses the information on the behavior of the state in past situations, which allows anticipating the measures to be taken and studying them with better precision.
#
# However, the article also has certain problems, it is clear that it has a large number of graphs and equations that make the article one aimed at an already specialized audience, so that people with basic knowledge in macroeconomics do not have enough knowledge to interpret all of them. the equations given in the text. In the same way, although it delves into the models, the conclusions it gives are quite incomplete, it does not delve into the results obtained and simply makes a superficial summary of what was done throughout the investigation. Likewise, a deeper historical framework could be provided, explaining what happened in the crisis and what the concept of unconventional policies refers to, and not simply start with graphs and equations.
#
# Based on this, a step to follow based on this research is to generate a comparative article. That is, the article highlights the old model too much, however it would be important to combine it and compare it with more recent economic models to see its degree of effectiveness and its objectivity when studying important historical events at an economic level. In the same way, it can be an interesting article to replicate with the crisis given by the pandemic, since unconventional policies were also taken, it would be important to generate investigations of this type with a crisis from which we continue to recover today.

# %% [markdown]
# #### Code part

# %% [markdown]
# #### Simultaneous equilibrium in money and goods markets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy

# %% [markdown]
# IS Curve:
#
# $$ r = \frac{B_o}{h} - \frac{B_1}{h}Y $$
#
# - Where $ B_0 = C_o + I_o + G_o + X_o $ and $ B_1 = 1 - (b - m)(1 - t) $

# %% [markdown]
# LM Curve:
#
# $$  r = -\frac{1}{j}\frac{Mo^s}{P_o} + \frac{k}{j}Y $$
#
# These equations can be reduced:
#
# $$ -\frac{1}{j}\frac{Mo^s}{P_o} + \frac{k}{j}Y = \frac{B_o}{h} - \frac{B_1}{h}Y $$
#
# $$ Y^e = \frac{j B_o}{k h + j B_1} + (\frac{h}{k h + j B_1})\frac{Ms_o}{P_o} $$
#
# - Equilibrium Interest Rate $ (r^e) $
#
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})\frac{Ms_o}{P_o} $$
#
# Equilibrium of the IS-LM model.

# %%
# IS Curve
Y_size = 100 
b = 0.4                 
m = 0.2                 
t = 0.9                  
Co = 20              
Io = 10                  
Go = 50                 
Xo = 2                  
h =  1                 

Y = np.arange(Y_size)

# %%
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
r
# Out:
# array([ 82.  ,  81.02,  80.04,  79.06,  78.08,  77.1 ,  76.12,  75.14,
#         74.16,  73.18,  72.2 ,  71.22,  70.24,  69.26,  68.28,  67.3 ,
#         66.32,  65.34,  64.36,  63.38,  62.4 ,  61.42,  60.44,  59.46,
#         58.48,  57.5 ,  56.52,  55.54,  54.56,  53.58,  52.6 ,  51.62,
#         50.64,  49.66,  48.68,  47.7 ,  46.72,  45.74,  44.76,  43.78,
#         42.8 ,  41.82,  40.84,  39.86,  38.88,  37.9 ,  36.92,  35.94,
#         34.96,  33.98,  33.  ,  32.02,  31.04,  30.06,  29.08,  28.1 ,
#         27.12,  26.14,  25.16,  24.18,  23.2 ,  22.22,  21.24,  20.26,
#         19.28,  18.3 ,  17.32,  16.34,  15.36,  14.38,  13.4 ,  12.42,
#         11.44,  10.46,   9.48,   8.5 ,   7.52,   6.54,   5.56,   4.58,
#          3.6 ,   2.62,   1.64,   0.66,  -0.32,  -1.3 ,  -2.28,  -3.26,
#         -4.24,  -5.22,  -6.2 ,  -7.18,  -8.16,  -9.14, -10.12, -11.1 ,
#        -12.08, -13.06, -14.04, -15.02])

# %%
Y_size = 100

k = 15                
j = 10                
Ms = 9000             
P  = 20         

Y = np.arange(Y_size)

# %%
def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)
i
# Out:
# array([-45. , -43.5, -42. , -40.5, -39. , -37.5, -36. , -34.5, -33. ,
#        -31.5, -30. , -28.5, -27. , -25.5, -24. , -22.5, -21. , -19.5,
#        -18. , -16.5, -15. , -13.5, -12. , -10.5,  -9. ,  -7.5,  -6. ,
#         -4.5,  -3. ,  -1.5,   0. ,   1.5,   3. ,   4.5,   6. ,   7.5,
#          9. ,  10.5,  12. ,  13.5,  15. ,  16.5,  18. ,  19.5,  21. ,
#         22.5,  24. ,  25.5,  27. ,  28.5,  30. ,  31.5,  33. ,  34.5,
#         36. ,  37.5,  39. ,  40.5,  42. ,  43.5,  45. ,  46.5,  48. ,
#         49.5,  51. ,  52.5,  54. ,  55.5,  57. ,  58.5,  60. ,  61.5,
#         63. ,  64.5,  66. ,  67.5,  69. ,  70.5,  72. ,  73.5,  75. ,
#         76.5,  78. ,  79.5,  81. ,  82.5,  84. ,  85.5,  87. ,  88.5,
#         90. ,  91.5,  93. ,  94.5,  96. ,  97.5,  99. , 100.5, 102. ,
#        103.5])

# %%
y_max = np.max(i)

fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Simultaneous equilibrium in money and goods markets", xlabel= r'Y', ylabel= r'r')

ax.plot(Y, r, "k-", label = "IS", color = "green")
ax.plot(Y, i, "b-", label="LM", color = "blue")

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle = ":", color = "black")
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle = ":", color = "black")
plt.plot(51, 32, marker="o", color="black", label = "E")
plt.text(49,38, 'E', fontsize = 14, color = 'black')

plt.text(99, 99, 'LM', fontsize=13)
plt.text(99, -11, 'IS', fontsize=13)
plt.text(48, 80, 'I', fontsize=13)
plt.text(80, 35, 'II', fontsize=13)
plt.text(48, -13, 'III', fontsize=13)
plt.text(20, 35, 'IV', fontsize=13)

ax.legend()
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/946531967.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/946531967.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "blue")

# %% [markdown]
# #### Comparative statics

# %% [markdown]
# #### Effect of an increase in Government Spending

# %%
Go = 65
def r_IS_G(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

def Y_IS_G(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_G = r_IS_G(b, m, t, Co, Io, Go, Xo, h, Y)
r_G
# Out:
# array([ 9.700e+01,  9.602e+01,  9.504e+01,  9.406e+01,  9.308e+01,
#         9.210e+01,  9.112e+01,  9.014e+01,  8.916e+01,  8.818e+01,
#         8.720e+01,  8.622e+01,  8.524e+01,  8.426e+01,  8.328e+01,
#         8.230e+01,  8.132e+01,  8.034e+01,  7.936e+01,  7.838e+01,
#         7.740e+01,  7.642e+01,  7.544e+01,  7.446e+01,  7.348e+01,
#         7.250e+01,  7.152e+01,  7.054e+01,  6.956e+01,  6.858e+01,
#         6.760e+01,  6.662e+01,  6.564e+01,  6.466e+01,  6.368e+01,
#         6.270e+01,  6.172e+01,  6.074e+01,  5.976e+01,  5.878e+01,
#         5.780e+01,  5.682e+01,  5.584e+01,  5.486e+01,  5.388e+01,
#         5.290e+01,  5.192e+01,  5.094e+01,  4.996e+01,  4.898e+01,
#         4.800e+01,  4.702e+01,  4.604e+01,  4.506e+01,  4.408e+01,
#         4.310e+01,  4.212e+01,  4.114e+01,  4.016e+01,  3.918e+01,
#         3.820e+01,  3.722e+01,  3.624e+01,  3.526e+01,  3.428e+01,
#         3.330e+01,  3.232e+01,  3.134e+01,  3.036e+01,  2.938e+01,
#         2.840e+01,  2.742e+01,  2.644e+01,  2.546e+01,  2.448e+01,
#         2.350e+01,  2.252e+01,  2.154e+01,  2.056e+01,  1.958e+01,
#         1.860e+01,  1.762e+01,  1.664e+01,  1.566e+01,  1.468e+01,
#         1.370e+01,  1.272e+01,  1.174e+01,  1.076e+01,  9.780e+00,
#         8.800e+00,  7.820e+00,  6.840e+00,  5.860e+00,  4.880e+00,
#         3.900e+00,  2.920e+00,  1.940e+00,  9.600e-01, -2.000e-02])

# %%
y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effect of increase in Goverment Spending (Go)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, "k-", label = "IS", color = "black")
ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, color = "red", label = 'IS_G')
ax.plot(Y, i, "b-", label="LM", color = "blue")  

plt.axvline(x=51.1,  ymin= 0, ymax= 0.52, linestyle = ":", color = "black")
plt.axhline(y=32, xmin= 0, xmax= 0.52, linestyle = ":", color = "black")
plt.plot(51, 32, marker="o", color="black", label = "Eo")
plt.text(49,36, 'Eo', fontsize = 14, color = 'black')

plt.axvline(x=57,  ymin= 0, ymax= 0.57, linestyle = ":", color = "black")
plt.axhline(y=41, xmin= 0, xmax= 0.57, linestyle = ":", color = "black")
plt.plot(57, 41, marker="o", color="grey", label = "E1")
plt.text(55.1,46, 'E1', fontsize = 14, color = 'grey')

plt.text(99, 99, 'LM', fontsize=13)
plt.text(99, -11, 'IS', fontsize=13)
plt.text(99, 2, 'ISo', fontsize=13)

ax.legend()
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2939198140.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(Y, r, "k-", label = "IS", color = "black")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2939198140.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, r_G, "b-",  scalex = t, scaley = t, color = "red", label = 'IS_G')
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2939198140.py:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-", label="LM", color = "blue")

# %%
pip install causalgraphicalmodels
# Out:
# Requirement already satisfied: causalgraphicalmodels in c:\programdata\anaconda3\lib\site-packages (0.0.4)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: graphviz in c:\programdata\anaconda3\lib\site-packages (from causalgraphicalmodels) (0.20)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from causalgraphicalmodels) (1.3.4)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from causalgraphicalmodels) (1.20.3)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from causalgraphicalmodels) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->causalgraphicalmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->causalgraphicalmodels) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->causalgraphicalmodels) (1.16.0)

# %%
import pandas as pd
import numpy as np
import random
import math
import sklearn
import scipy as sp
import networkx
import matplotlib
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col
import sympy
# import dowhy as dw
from causalgraphicalmodels import CausalGraphicalModel

# %%
Y_size = 100
k = 20                
j = 10                
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


Y_size = 100            
k = 20                
j = 10               
Ms = 30000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100
c = 20                
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 55              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Aumento en la cantidad de dinero", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", label="LM_0", color = "green")
ax.plot(Y, i, "r-",label="IS_0", color = "blue")
ax.plot(Y, i_1, "r-",linestyle='dashed',label="LM_1", color = "black")
plt.axvline(x=51,  ymin=-100, ymax= 0.6, linestyle = "dotted", color = "black")
plt.axhline(y=1, xmin=-100, xmax= 0.5, linestyle = "dotted", color = "black")  
plt.axvline(x=64,  ymin=-100, ymax= 0.52, linestyle = "dotted", color = "black")
plt.axhline(y=-23, xmin=-100, xmax= 0.63, linestyle = "dotted", color = "black")
plt.text(90, 100, "LM(Ms,Po)", color='green')
plt.text(90, 50, "LM'(M1,Po)", color='blue')
plt.text(95, -70, "IS", color='black')
ax.legend()
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2256245997.py:51: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "b-", label="LM_0", color = "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2256245997.py:52: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",label="IS_0", color = "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2256245997.py:53: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed',label="LM_1", color = "black")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2256245997.py:53: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed',label="LM_1", color = "black")

# %% [markdown]
# If quantity of money increases, an excess supply is generated in the money market. Therefore the interest rate fall to the initial equilibrium level. This increases investment and income. With a low rate, the final balance increases the investment and is located at a higher level than the initial balance.

# %% [markdown]
# $$ ∆𝒀 = (𝒉/𝒌𝒉 + 𝒋𝜷𝟏) ∆𝑴^𝒔𝟎/𝑷𝟎 > 𝟎 $$
# $$ ∆𝒓 = −(𝜷𝟏/𝒌𝒉 + 𝒋𝜷𝟏) ∆𝑴^𝒔𝟎/𝑷𝟎 <𝟎 $$

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = 20000           
P  = 20              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100            
k = 20              
j = 10               
Ms = 30000         
P  = 20              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100
c = 20                
b = 0.5                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 2             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 40                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 10           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  

def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Política Monetaria expansiva y Fiscal restrictiva", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", label="LM", color = "blue")
ax.plot(Y, i, "r-",label="IS", color = "green")
ax.plot(Y, i_2, "r-",linestyle='dashed',label="IS'", color= "red")
ax.vlines(x=52.1, ymin=-100, ymax=3,linestyle='dotted', colors='black')
ax.vlines(x=60, ymin=-100, ymax=20,linestyle='dotted', colors='black')
ax.hlines(y=18, xmin=-8, xmax=60,linestyle='dotted', colors='black')
ax.hlines(y=5, xmin=-8, xmax=53,linestyle='dotted', colors='black')
plt.text(95, 100, "LM", color='black')
plt.text(95, -25, "IS'", color='black')
plt.text(95, -75, "IS", color='black')
plt.text(-10, 20, "r1", color='black')
plt.text(-10, 8, "r0'", color='black')
plt.text(50, -100, "Y0", color='black')
plt.text(60, -100, "Y1", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1795605912.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", label="LM", color = "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1795605912.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",label="IS", color = "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1795605912.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed',label="IS'", color= "red")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1795605912.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed',label="IS'", color= "red")

# %% [markdown]
# #### DA-OA

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 40 
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo DA-OA:Política Fiscal Expansiva", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM", color = "purple")
ax.plot(Y, i, "r-",linestyle='dashed', label="IS", color = "orange")
ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "blue")
ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "blue")
ax.vlines(x=55.5, ymin=-100, ymax=82,linestyle='dotted', colors='black')
ax.hlines(y=78, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, 'LM (P0)', color='black')
plt.text(20, 160, "LM'(P1)", color='black')
plt.text(20, 0, "IS'", color='black')
plt.text(20, -40, "IS", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM", color = "purple")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM", color = "purple")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='dashed', label="IS", color = "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='dashed', label="IS", color = "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1594441018.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "blue")

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
Y_size = 100
c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo DA-OA: Política Fiscal Expansiva", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='none')
ax.plot(Y, i, "r-",linestyle='dashed')
ax.plot(Y, i_2, "r-",linestyle='solid', color= "blue")
ax.plot(Y, i_1, "r-",linestyle='solid', color= "orange")
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, 'DA', color='black')
plt.text(20, 120, "DA'", color='black')
plt.text(20, -40, "OA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1227743599.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='none')
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1227743599.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='dashed')
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1227743599.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1227743599.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1227743599.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1227743599.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "orange")

# %%
Y_size = 100
k = 20                
j = 10                
Ms = 10000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
             
k = 20                
j = 10               
Ms = 15000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100
             
k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 30                
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 30            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo OA-DA: Política Monetaria Contractiva", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_2, "b-", linestyle='dotted', label="LM_2", color = 'orange')
ax.plot(Y, i, "r-",label="IS_0")
ax.plot(Y, i_1, "r-",linestyle='dashed', color = "skyblue")
ax.plot(Y, i_0, "r-", color = "blue")
ax.vlines(x=55, ymin=-100, ymax=10,linestyle='dotted', colors='black')
ax.hlines(y=35, xmin=-8, xmax=43,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=8, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.vlines(x=48, ymin=-100, ymax=26,linestyle='dotted', colors='black')
ax.vlines(x=42.5, ymin=-100, ymax=31,linestyle='dotted', colors='black')
plt.text(20, 0.5, 'LM (M1, P0)', color='black')
plt.text(20, 80, "IS", color='black')
plt.text(20, -40, "LM (M1, P1)", color='black')
plt.text(20, -70, "LM (Mo, Po)", color='black')
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1956614651.py:4: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "b-", linestyle='dotted', label="LM_2", color = 'orange')
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1956614651.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "b-", linestyle='dotted', label="LM_2", color = 'orange')
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1956614651.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color = "skyblue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1956614651.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color = "skyblue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1956614651.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", color = "blue")

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo OA-DA: Política Monetaria Contractiva ", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='none')
ax.plot(Y, i, "r-",linestyle='solid', color = "orange")
ax.plot(Y, i_2, "r-",linestyle='dashed', color= "green")
ax.plot(Y, i_1, "r-",linestyle='solid', color= "skyblue")
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, "DA'", color='black')
plt.text(20, 120, "OA", color='black')
plt.text(20, -40, "DA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2249030541.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='none')
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2249030541.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', color = "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2249030541.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', color = "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2249030541.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed', color= "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2249030541.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed', color= "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2249030541.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "skyblue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2249030541.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "skyblue")

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100
c = 40                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Expectativas: Efectos de un aumento en el precio esperado (de > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='solid', color= "green")
ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")
ax.vlines(x=48, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=63, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=45, xmin=-8, xmax=56,linestyle='dotted', colors='black')
ax.vlines(x=57, ymin=-100, ymax=48,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 0, "LM'(P1)", color='black')
plt.text(20, -40, "LM (P0)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1901132634.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1901132634.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1901132634.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1901132634.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1901132634.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/1901132634.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")

# %%
Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

c = 40                
b = 0.1                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Expectativas: Efectos de un aumento en el precio esperado (de > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "skyblue")
ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "orange")
ax.vlines(x=42.5, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=52, xmin=-8, xmax=43,linestyle='dotted', colors='black')
ax.hlines(y=35, xmin=-8, xmax=51,linestyle='dotted', colors='black')
ax.vlines(x=51.5, ymin=-100, ymax=35,linestyle='dotted', colors='black')
plt.text(20, 80, 'DA', color='black')
plt.text(20, 0, "OA'", color='black')
plt.text(20, -40, "OA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/163747771.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/163747771.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/163747771.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "skyblue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/163747771.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "skyblue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/163747771.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/163747771.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "orange")

# %%
Y_size = 100
           
k = 20                
j = 8              
Ms = 1000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100            
k = 20              
j = 8               
Ms = 8000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
c = 40                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1

# %%
Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Oferta: efectos de un aumento en el producto potencial (dY > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
ax.plot(Y, i, "r-",linestyle='solid', label="IS_0" , color = "green")
ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
ax.plot(Y, i_1, "r-",linestyle='dashed', color= "brown")
ax.vlines(x=50, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=59, xmin=-8, xmax=50,linestyle='dotted', colors='black')
ax.hlines(y=85, xmin=-8, xmax=35,linestyle='dotted', colors='black')
ax.vlines(x=35.5, ymin=-100, ymax=84,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 25, "LM'(P0)", color='black')
plt.text(20, -30, "LM (P1)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/3562293332.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/3562293332.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0" , color = "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/3562293332.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0" , color = "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/3562293332.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/3562293332.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/3562293332.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "brown")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/3562293332.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "brown")

# %%
Y_size = 100
           
k = 20                
j = 12           
Ms = 1000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

Y_size = 100            
k = 20              
j = 12             
Ms = 8000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

# %%
c = 50               
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 50
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 50                
b = 0.01

# %%
m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 50             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

# %%
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Oferta: efectos de un aumento en el producto potencial (dY > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color = "blue")
ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
ax.plot(Y, i_1, "r-",linestyle='dashed', color= "green")
ax.vlines(x=37.5, ymin=-100, ymax=62,linestyle='dotted', colors='black')
ax.hlines(y=59, xmin=-8, xmax=38.5,linestyle='dotted', colors='black')
ax.hlines(y=38, xmin=-8, xmax=50,linestyle='dotted', colors='black')
ax.vlines(x=49.5, ymin=-100, ymax=39,linestyle='dotted', colors='black')
plt.text(20, 100, 'DA', color='black')
plt.text(20, 25, "OA", color='black')
plt.text(20, -30, "OA'", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2530983616.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2530983616.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color = "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2530983616.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color = "blue")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2530983616.py:8: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2530983616.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2530983616.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "green")
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_8972/2530983616.py:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "green")
