# %% [markdown]
# # Report 9

# %% [markdown]
# Mendoza, Waldo. (2015). Demanda y oferta agregada en presencia de políticas monetarias no convencionales.
# 20171501

# %% [markdown]
# The objective of the article is to talk about monetary non conventional politics, applied in the international crisis from 2008-2009. It shows how the Federal Reserve used interest rate to fund markets.
# The article works with two non conventional instruments: future path of the short-term interest rate and direct intervention in the long-term bond market. One of the reasons to write it, is to show that old methods (keynes, Hicks and Tobin) can be still useful in nowadays macroeconomic problems.
#
# One of the more identifiable strength of the article is that it gets back to the begining of the topics, explains what are the models before assuming the reader knows about it.
# On the other side, it highlights that one of its weakness can be that it may be too focused on the contemporary models rather than the non conventional ones, then rather that explain us details of it, we would know more about contemporary ones.

# %%
#Code Secction

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy

# %% [markdown]
# Equation of the IS Curve:
# $$ r = \frac{B_o}{h} - \frac{B_1}{h}Y $$

# %% [markdown]
# Equation of the LM Curve
# $$  r = -\frac{1}{j}\frac{Mo^s}{P} + \frac{k}{j}Y $$

# %% [markdown]
# # Equilibrio simultaneo de bienes y gobierno

# %%
Y_size = 100             
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

# %%
b = 0.01               
m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS
i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Equilibrio simultáneo en mercados de bienes y de dinero", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-",color='lightblue', label="LM_0")
ax.plot(Y, i, "r-",color='yellow',label="IS_0")
ax.vlines(x=47, ymin=-120, ymax=-3,linestyle='dotted', colors='black')
ax.hlines(y=-4, xmin=-8, xmax=47,linestyle='dotted', colors='black')
plt.text(52, -9, 'E=( Y0, r0 )', color='black')
ax.legend()  
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1571230563.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "b-",color='lightblue', label="LM_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1571230563.py:27: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",color='yellow',label="IS_0")

# %% [markdown]
# # Efecto de aumento de gasto del gobierno

# %%
import numpy as np               
import matplotlib.pyplot as plt  
k = 20             
j = 10               
Ms = 20000            
P  = 20               
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

#-------------------------------------   

Y_size = 100
c = 20                
b = 0.01               

m = 0.9           
T = 1              
I_bar = 10           
G_bar = 50             
X_bar = 2             
h = 1                 

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

#---------------------------------------------------
c = 40                
b = 0.05               
                          
I_bar = 10            
G_bar = 70
X_bar = 2             
h = 1  

def i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_1 = i_IS_1(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                      
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Efecto de un aumento del Gasto del Gobierno", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", label="LM_0")
ax.plot(Y, i, "r-",color='yellow',label="IS_0")
ax.plot(Y, i_1, "r-",linestyle='dotted',color= "green", label="IS_1")
ax.vlines(x=59, ymin=-100, ymax=20,linestyle='dotted', colors='black')
ax.vlines(x=47, ymin=-100, ymax=-6,linestyle='dotted', colors='black')
ax.hlines(y=18, xmin=-8, xmax=60,linestyle='dotted', colors='black')
ax.hlines(y=-7, xmin=-8, xmax=48,linestyle='dotted', colors='black')
plt.text(95, 100, "LM", color='black')
plt.text(95, -45, "IS'", color='black')
plt.text(95, -95, "IS", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2047915373.py:66: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",color='yellow',label="IS_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2047915373.py:67: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dotted',color= "green", label="IS_1")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2047915373.py:67: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dotted',color= "green", label="IS_1")

# %% [markdown]
# # Efecto del aumento de cantidad de dinero

# %%
k = 20                
j = 10                
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

             
Ms = 30000                     


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

#---------------------------------------------------

Y_size = 100
c = 20                
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 20            
G_bar = 55              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Efecto de un aumento en la cantidad de dinero", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", label="LM_0")
ax.plot(Y, i, "r-",color='green',label="IS_0")
ax.plot(Y, i_1, "r-",linestyle='dashed',label="LM_1", color = "pink")
plt.axvline(x=51,  ymin=-100, ymax= 0.6, linestyle = "dotted", color = "black")
plt.axhline(y=1, xmin=-100, xmax= 0.5, linestyle = "dotted", color = "black")  
plt.axvline(x=64,  ymin=-100, ymax= 0.52, linestyle = "dotted", color = "black")
plt.axhline(y=-23, xmin=-100, xmax= 0.63, linestyle = "dotted", color = "black")
plt.text(70, 20, '→', fontsize=50, color='grey')
plt.text(90, 100, "LM(MsO,Po)", color='black')
plt.text(90, 50, "LM'(Ms1,Po)", color='black')
plt.text(95, -70, "IS", color='black')
ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3254240927.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",color='green',label="IS_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3254240927.py:50: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed',label="LM_1", color = "pink")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3254240927.py:50: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed',label="LM_1", color = "pink")

# %% [markdown]
# # EFECTOS DE POLITICA MONETARIA Y FISCAL RESTRICTIVA

# %%
k = 20                
j = 10              
Ms = 20000           
P  = 20              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
k = 20              
j = 10               
Ms = 30000         
P  = 20              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   
c = 20                
b = 0.5                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 2             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

c = 40                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 10           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Efectos de una Política Monetaria expansiva y Fiscal restrictiva", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", label="LM_0")
ax.plot(Y, i, "r-",label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='dashed',label="LM_2", color= "purple")
ax.vlines(x=52.1, ymin=-100, ymax=3,linestyle='dotted', colors='black')
ax.vlines(x=60, ymin=-100, ymax=20,linestyle='dotted', colors='black')
ax.hlines(y=18, xmin=-8, xmax=60,linestyle='dotted', colors='black')
ax.hlines(y=5, xmin=-8, xmax=53,linestyle='dotted', colors='black')
plt.text(95, 100, "LM", color='black')
plt.text(95, -25, "IS'", color='black')
plt.text(95, -75, "IS", color='black')
plt.text(-10, 20, "r1", color='black')
plt.text(-10, 8, "r0'", color='black')
plt.text(50, -100, "Y0", color='black')
plt.text(60, -100, "Y1", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3477837928.py:77: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed',label="LM_2", color= "purple")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3477837928.py:77: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed',label="LM_2", color= "purple")

# %% [markdown]
# # MODELO DA-OA

# %%
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)


c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


c = 40                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo DA-OA: Efectos de una Política Fiscal Expansiva (dG0 > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
ax.plot(Y, i, "r-",linestyle='dashed', label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "brown")
ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "orange")
ax.vlines(x=55.5, ymin=-100, ymax=82,linestyle='dotted', colors='black')
ax.hlines(y=78, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, 'LM (P0)', color='black')
plt.text(20, 160, "LM'(P1)", color='black')
plt.text(20, 0, "IS'", color='black')
plt.text(20, -40, "IS", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2780163404.py:78: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2780163404.py:79: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='dashed', label="IS_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2780163404.py:80: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "brown")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2780163404.py:80: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "brown")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2780163404.py:81: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "orange")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2780163404.py:81: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "orange")

# %% [markdown]
# # MODELO DA-OA

# %%
           
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)


c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo DA-OA: Efectos de una Política Fiscal Expansiva (dG0 > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='none')
ax.plot(Y, i, "r-",linestyle='dashed')
ax.plot(Y, i_2, "r-",linestyle='solid', color= "gray")
ax.plot(Y, i_1, "r-",linestyle='solid', color= "pink")
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, 'DA', color='black')
plt.text(20, 120, "DA'", color='black')
plt.text(20, -40, "OA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator()) 
ax.legend() 
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1253650010.py:76: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='none')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1253650010.py:77: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='dashed')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1253650010.py:78: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "gray")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1253650010.py:78: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "gray")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1253650010.py:79: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "pink")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1253650010.py:79: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "pink")
# No handles with labels found to put in legend.

# %% [markdown]
# # MODELO OA-DA

# %%
k = 20                
j = 10                
Ms = 10000             
P  = 20                
Y = np.arange(Y_size)  
def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_2 = i_LM_0( k, j, Ms, P, Y)

k = 20                
j = 10               
Ms = 15000             
P  = 20                
Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

k = 20                
j = 10               
Ms = 20000             
P  = 20                
Y = np.arange(Y_size)  


def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

c = 30                
b = 0.01                
m = 0.9           
T = 1                  
I_bar = 30            
G_bar = 50              
X_bar = 2              
h = 1                  
Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                       
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo OA-DA: efectos de una Política Monetaria Contractiva (dM^s0 < 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_2, "b-", linestyle='dotted', label="LM_2", color = 'blue')
ax.plot(Y, i, "r-",label="IS_0")
ax.plot(Y, i_1, "r-",linestyle='dashed', color = "purple")
ax.plot(Y, i_0, "r-", color = "yellow")
ax.vlines(x=55, ymin=-100, ymax=10,linestyle='dotted', colors='black')
ax.hlines(y=35, xmin=-8, xmax=43,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=8, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.vlines(x=48, ymin=-100, ymax=26,linestyle='dotted', colors='black')
ax.vlines(x=42.5, ymin=-100, ymax=31,linestyle='dotted', colors='black')
plt.text(20, 0.5, 'LM (M1, P0)', color='black')
plt.text(20, 80, "IS", color='black')
plt.text(20, -40, "LM (M1, P1)", color='black')
plt.text(20, -70, "LM (Mo, Po)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator()) 
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1999883033.py:59: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "b-", linestyle='dotted', label="LM_2", color = 'blue')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1999883033.py:59: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "b-", linestyle='dotted', label="LM_2", color = 'blue')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1999883033.py:61: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color = "purple")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1999883033.py:61: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color = "purple")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/1999883033.py:62: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", color = "yellow")

# %% [markdown]
# # MODELO OA-DA

# %%
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
  

c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)
v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Modelo OA-DA: efectos de una Política Monetaria Contractiva (dMs0 < 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='none')
ax.plot(Y, i, "r-",linestyle='solid')
ax.plot(Y, i_2, "r-",linestyle='dashed', color= "purple")
ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, "DA'", color='black')
plt.text(20, 120, "OA", color='black')
plt.text(20, -40, "DA", color='black')  
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator()) 
ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/464742578.py:75: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='none')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/464742578.py:76: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid')
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/464742578.py:77: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed', color= "purple")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/464742578.py:77: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed', color= "purple")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/464742578.py:78: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/464742578.py:78: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")
# No handles with labels found to put in legend.

# %% [markdown]
# # Shock de expectativas

# %%
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 40                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  
def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Expectativas: Efectos de un aumento en el precio esperado (de > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='solid', color= "green")
ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")
ax.vlines(x=48, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=63, xmin=-8, xmax=48,linestyle='dotted', colors='black')
ax.hlines(y=45, xmin=-8, xmax=56,linestyle='dotted', colors='black')
ax.vlines(x=57, ymin=-100, ymax=48,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 0, "LM'(P1)", color='black')
plt.text(20, -40, "LM (P0)", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2870307579.py:81: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2870307579.py:82: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2870307579.py:83: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "green")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2870307579.py:83: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid', color= "green")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2870307579.py:84: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/2870307579.py:84: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid', color= "blue")

# %% [markdown]
# # Shock de expectativas

# %%
k = 20                
j = 10              
Ms = 10000           
P  = 30              
Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)

k = 20              
j = 10               
Ms = 10000         
P  = 15              
Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)

c = 40                
b = 0.1                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  

def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS
i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Expectativas: Efectos de un aumento en el precio esperado (de > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "green")
ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "purple")
ax.vlines(x=42.5, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=52, xmin=-8, xmax=43,linestyle='dotted', colors='black')
ax.hlines(y=35, xmin=-8, xmax=51,linestyle='dotted', colors='black')
ax.vlines(x=51.5, ymin=-100, ymax=35,linestyle='dotted', colors='black')
plt.text(20, 80, 'DA', color='black')
plt.text(20, 0, "OA'", color='black')
plt.text(20, -40, "OA", color='black') 
ax.legend()
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator()) 
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3307631297.py:68: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='dashed', label="LM_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3307631297.py:69: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='none', label="IS_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3307631297.py:70: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "green")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3307631297.py:70: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "green")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3307631297.py:71: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "purple")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/3307631297.py:71: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "purple")

# %%
k = 20                
j = 8              
Ms = 1000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
            
k = 20              
j = 8               
Ms = 8000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)


c = 44                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 40
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS
i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 20             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Oferta: efectos de un aumento en el producto potencial (dY > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color="green")
ax.plot(Y, i_2, "r-",linestyle='none', color= "blue")
ax.plot(Y, i_1, "r-",linestyle='dashed', color= "yellow")
ax.vlines(x=51, ymin=-100, ymax=60,linestyle='dotted', colors='black')
ax.hlines(y=60, xmin=-8, xmax=50,linestyle='dotted', colors='black')
ax.hlines(y=85, xmin=-8, xmax=35,linestyle='dotted', colors='black')
ax.vlines(x=36, ymin=-100, ymax=84,linestyle='dotted', colors='black')
plt.text(20, 100, 'IS', color='black')
plt.text(20, 25, "LM'(P0)", color='black')
plt.text(20, -30, "LM (P1)", color='black')
ax.legend()  
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4148898359.py:73: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4148898359.py:74: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color="green")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4148898359.py:74: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color="green")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4148898359.py:75: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "blue")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4148898359.py:75: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "blue")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4148898359.py:76: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "yellow")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4148898359.py:76: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "yellow")

# %% [markdown]
# # Shock de oferta

# %%
k = 20                
j = 12           
Ms = 1000           
P  = 30              
Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)


k = 20              
j = 12             
Ms = 8000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)


c = 50               
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 50
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)


c = 50                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 50             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)

y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Shock de Oferta: efectos de un aumento en el producto potencial (dY > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color="brown")
ax.plot(Y, i_2, "r-",linestyle='none', color= "yellow")
ax.plot(Y, i_1, "r-",linestyle='dashed', color= "blue")
ax.vlines(x=37.5, ymin=-100, ymax=62,linestyle='dotted', colors='black')
ax.hlines(y=59, xmin=-8, xmax=38.5,linestyle='dotted', colors='black')
ax.hlines(y=38, xmin=-8, xmax=50,linestyle='dotted', colors='black')
ax.vlines(x=49.5, ymin=-100, ymax=39,linestyle='dotted', colors='black')
plt.text(55, 80, '→', fontsize=40, color='grey')
plt.text(20, 26, "OA", color='black')
plt.text(20, -31, "OA'", color='black')
plt.text(20, 100, 'DA', color='black')
ax.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4233107313.py:75: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "r-", linestyle='solid', label="LM_0")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4233107313.py:76: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color="brown")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4233107313.py:76: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i, "r-",linestyle='solid', label="IS_0", color="brown")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4233107313.py:77: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "yellow")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4233107313.py:77: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "yellow")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4233107313.py:78: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "blue")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_21104/4233107313.py:78: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax.plot(Y, i_1, "r-",linestyle='dashed', color= "blue")
