# %% [markdown]
# Yarim Kamila Gamarra Dávila - 20195573

# %% [markdown]
# I. Report of the article “Demanda y oferta agregada en presencia de políticas monetarias no convencionales”
#
# The aim of this article is to model the effects of the unconventional monetary policy applied during the international crisis of 2008-2009 in order to counter the economic consequences. To achieve this objective, the author decided to extend the standard model of aggregate demand and supply in a closed economy to incorporate monetary policy innovations. In this way, the author looked to demonstrate that old models are still useful to analyze contemporary issues.
#
# First, on the advantages, the article includes a detailed explanation of the different models using equations and graphics. I believe this is important because it helps to understand the process of the construction of the model and the effects of the policies in the economy. In addition, the article is analyzing an event that happened seven years before the article was published. I consider this as an advantage because the author could analyze the immediate effects of the unconventional policies, but also could see their repercussion in a long therm. Moreover, the author included the conclusions and variations of models that other authors found. So, in this way, the work becomes more relevant, reliable, and complete. Finally, I believe it is an advantage that the authors used old models to analyze a contemporary issue because they are more general, comprehensive and also allows to break the myth that they are obsolete.
#
# Second, despite the importance of the points mentioned before, I believe there are some weaknesses that are important to mention. On one hand, despite the relevance of presenting a really detailed theoretical explanation, in my opinion, it would have been more relevant if the author could applied it to the crisis of the 2008-2009. In other words, it would have been interesting if the author used real data in order to have a better comprehension of the model and of the crisis and their impact. On the other hand, the article does not include an historical approach or political and social aspects in the analysis. In consider this as a weakness because it omits some factor that could have had an impact in the economy or in the effect of the unconventional politics. Finally, in my opinion, being the crisis of the 2008-2009 an international issue, it would have been relevant if the author included the effects of this unconventional policies in other countries than directly depend of the economy of the United States.
#
# In conclusion, I consider this is an important and relevant article because it helps to have a macroeconomic approach to one of the most dramatic crisis in the world. In addition, the model constructed helps to understand the effects of the unconventional policies applied in order to reduce the negative effects of the crisis. Moreover, this article helps to revalue old models that can be important to understand contemporary issues. In this way, I consider that a next step is to use this model to see if it can be applied in other economies. For example, in Latin America, even though we are not in a crisis like the 2008-2009, we are in constant recessions. In this way, it would be interesting to analyze if this model of unconventional policies can be useful to reactivate the economy and make it grow. In addition, it would be interesting, in one hand, to analyze the effects that this crisis had in regions like Latin America and, in the other hand, see if the unconventional politics applied in the United States had repercussions or indirect effects in the Latin American economy. Finally, another step would be to see if this kind of politics could also be useful to reduce the effects of other international crisis, like the pandemic.

# %% [markdown]
# II. Code Section

# %% [markdown]
# * 2.2

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  


def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title=" Effects of an Expansionary Fiscal Policy (dG0 > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", linestyle='none')
ax.plot(Y, i, "b-",linestyle='dashed')
ax.plot(Y, i_2, "b-",linestyle='solid', color= "blue")
ax.plot(Y, i_1, "b-",linestyle='solid', color= "orange")
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, 'DA', color='black')
plt.text(20, 120, "DA'", color='black')
plt.text(20, -40, "OA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.plot(47, 23, marker="o", color="black", label = "Eo")
plt.text(45, 30,'Eo', fontsize = 14, color = 'black')

plt.plot(56, 43, marker="o", color="midnightblue", label = "E_G")
plt.text(53,50, 'E_G', fontsize = 14, color = 'blue')

plt.text(28, 67, '∆Go', fontsize=12, color='black')
plt.text(28, 60, '→', fontsize=15, color='black')

plt.text(50, -50, '→', fontsize=20, color='grey')
plt.text(20, 25, '↑', fontsize=20, color='grey')


plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/988745419.py:86: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "b-", linestyle='none')
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/988745419.py:87: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-",linestyle='dashed')
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/988745419.py:88: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "b-",linestyle='solid', color= "blue")
# ...

# %% [markdown]
# * Intuition
#
# 1. Effects on the GDP (Y)
#
# \begin{align}
#     G_0↑→ DA↑→ DA>Y→ Y↑
# \end{align}
#
# In the goods market, if the government spending increases, the aggregate demand will also increse. In this way, it will become greater that the production level, so, to return to equilibrium, the production level has to increase
#
#
# 2. Effects on the interest rate (r)
#
# \begin{align}
#    Y↑→ M^d↑→ M^d>M^o→ r↑
# \end{align}
#
# In the money market, the increase in the production level causes an increase in the money demand. This becomes greater that the money supply, so, to return to equilibrium, the interest rate has to increase
#
# 3. Efeccts on the level of prices (P)
#
# \begin{align}
#    Y↑→ (Y- 𝐘̅)↑→ P↑
# \end{align}
#
# The increase in the production level makes the difference between the real GDP and the expected GDP also increases. Finally, the level of prices also increases.
#
#
# * Math
#
# 1. Effects on the GDP (Y)
#
# \begin{align}
#    \frac {ΔY}{ΔG_0}  &=  \frac {-j}{|A|}  \ > 0\
# \end{align}
#
#
# 2. Effects on the interest rate (r)
#
# \begin{align}
#    \frac {Δr}{ΔG_0}  &=  \frac {- (k + \frac {0M_0^s} {P_0^2)}} {|A|} \ < 0\
# \end{align}
#
#
# 3. Efeccts on the level of prices (P)
#
# \begin{align}
#    \frac {ΔP}{ΔG_0}  &=  \frac {-0j}{|A|}  \ > 0\
# \end{align}

# %% [markdown]
# * 2.3

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 10              
Ms = -2000          
P  = 10              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------  

Y_size = 100
c = 20                
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 10                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)  

def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of a contractory Monetary Policy (dMs0 < 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", linestyle='none')
ax.plot(Y, i, "b-",linestyle='solid')
ax.plot(Y, i_2, "r-",linestyle='dashed', color= "blue")
ax.plot(Y, i_1, "r-",linestyle='solid', color= "orange")
ax.vlines(x=56, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=48, xmin=-8, xmax=55,linestyle='dotted', colors='black')
ax.hlines(y=25, xmin=-8, xmax=46,linestyle='dotted', colors='black')
ax.vlines(x=46, ymin=-100, ymax=28,linestyle='dotted', colors='black')
plt.text(20, 80, "DA'", color='black')
plt.text(20, 120, "DA", color='black')
plt.text(20, -40, "OA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())

plt.plot(56, 50, marker="o", color="black", label = "Eo")
plt.text(55,55, 'Eo', fontsize = 14, color = 'black')

plt.plot(46, 28, marker="o", color="midnightblue", label = "Eo_Ms")
plt.text(42, 35, 'Eo_Ms', fontsize = 14, color = 'blue')
plt.text(50, -100, '←', fontsize=18, color='grey')
plt.text(20, 30, '↓', fontsize=18, color='grey')

plt.text(10, 100, '∆Ms', fontsize=12, color='black')
plt.text(13, 90, '←', fontsize=15, color='grey')

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/3139640679.py:85: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "b-", linestyle='none')
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/3139640679.py:86: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-",linestyle='solid')
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/3139640679.py:87: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='dashed', color= "blue")
# ...

# %% [markdown]
# * Intuition
#
# 1. Effects on the interest rate (r)
#
# \begin{align}
#     M_0^s↓→ M_0^s<M^d→ r↑
# \end{align}
#
# In the money market, if the money supply decreases, it becomes lower that the money demand. So, to return to equilibrium, the interest rate must increase
#
# 2. Effects on the GDP (Y)
#
# \begin{align}
#    r↑→ I↓→ DA↓→ DA<Y→ Y↓
# \end{align}
#
# In the good market, the decrease in the interest rate causes a decrease in the investment. Consequently, the aggregate demand will also decrease and become lower than the production level. In this way, to return to equilibrium, the production level has to decrease.
#
# 3. Efeccts on the level of prices (P)
#
# \begin{align}
#    Y↓→ (Y- 𝐘̅)↓→ P↓
# \end{align}
#
# Because of the decrease in the production level, the difference between the real GDP and the expected GDP will decrease. Consequently, the levwl of prices will also decrease.
#
# * Math
#
# 1. Effects on the GDP (Y)
#
# \begin{align}
#    \frac {ΔY}{ΔM_0^s}  &=  \frac {-h}{|A|P_0}  \ > 0\
# \end{align}
#
#
# 2. Effects on the interest rate (r)
#
# \begin{align}
#    \frac {Δr}{ΔM_0^s}  &=  \frac {1-b(1-t)}{|A|P_0}  \ < 0\
# \end{align}
#
#
# 3. Efeccts on the level of prices (P)
#
# \begin{align}
#    \frac {ΔP}{ΔM_0^s}  &=  \frac {-0h}{|A|P_0}  \ > 0\
# \end{align}
#
#     So,
#
# \begin{align}
#    \frac {ΔP}{ΔY}  &=  \ 0 \ > 0\
# \end{align}

# %% [markdown]
# * 2.4

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 10              
Ms = 10000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 10               
Ms = 10000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 40                
b = 0.1                        
m = 0.9           
T = 1                 
I_bar = 10            
G_bar = 70
X_bar = 10             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 100                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 90           
G_bar = 50             
X_bar = 2            
h = 1               

Y = np.arange(Y_size)

def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of ana increase in the Expected Prices (de > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", linestyle='dashed', label="LM_0")
ax.plot(Y, i, "b-",linestyle='none', label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "orange")
ax.plot(Y, i_1, "r-",linestyle='solid',label="LM_1", color= "blue")
ax.vlines(x=42.5, ymin=-100, ymax=50,linestyle='dotted', colors='black')
ax.hlines(y=52, xmin=-8, xmax=43,linestyle='dotted', colors='black')
ax.hlines(y=35, xmin=-8, xmax=51,linestyle='dotted', colors='black')
ax.vlines(x=51.5, ymin=-100, ymax=35,linestyle='dotted', colors='black')
plt.text(20, 80, 'DA', color='black')
plt.text(20, 0, "OA'", color='black')
plt.text(20, -40, "OA", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())  

plt.plot(52, 42, marker="o", color="black", label = "Eo")
plt.text(50, 46, 'Eo', fontsize = 14, color = 'black')

plt.plot(42, 59, marker="o", color="midnightblue", label = "Eo_Pe")
plt.text(38, 64, 'Eo_Pe', fontsize = 14, color = 'blue')

plt.text(47, -100, '←', fontsize=18, color='grey')
plt.text(20, 37, '↑', fontsize=18, color='grey')

plt.text(75, 100, '∆Pe', fontsize=12, color='black')
plt.text(76, 90, '←', fontsize=15, color='grey')

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/3634299589.py:85: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "b-", linestyle='dashed', label="LM_0")
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/3634299589.py:86: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-",linestyle='none', label="IS_0")
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/3634299589.py:87: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='solid',label="LM_2", color= "orange")
# ...

# %% [markdown]
# * Intuition
#
# 1. Effects on the level of prices (P)
# \begin{align}
# P^e↑ - P↑ - Y↓
# \end{align}
# There ir a rise in the expected prices, tis means, prices in the future are going to rise. Because of this, there will be a contraction of the OA curve, going from P_0 to P_1. The level of production falls and the level of prices rises.
#
# 2. Effects on the interest rate (r)
# \begin{align}
# Y↓ - Md↓ - Md < \frac {M^s}{P}\ - r ↑
# \end{align}
#
# 3. Effects on the GDP (Y)
#
# The increase in the price causes a decrease in the level of production. This causes that the money demand will decrease, so, to return to equilibrium, the interest rate has to increase.
#
# \begin{align}
# P↑ - Y↓
# \end{align}
#
# Other cause of the fall in the level of production is that, as the price level increases and the interest rate rises,the AD curve reduces because the level of investment is reduced.
#
# \begin{align}
# r ↑ - I ↓ - DA ↓ - DA < Y - Y ↓
# \end{align}
#
# Because of the rise in the interest rate, the investment will decrease and also the aggregate demand. In this way, it will be lower that the level of production, so to return to equilibrium, the level of production has to decrease.
#
# * Math
#
# 1. Effects on the level of prices (P)
#
# \begin{align}
#    \ ΔP &= ΔP^e
# \end{align}
#
# \begin{align}
# \frac {ΔP}{ΔP^e}\ &= 1
# \end{align}
#
# \begin{align}
# 1 &> 0
# \end{align}
#
# \begin{align}
#    ΔP^e &> 0
# \end{align}
#
# 2.  Effects on the GDP (Y)
#
# \begin{align}
#    \ ΔP^e &= -KΔY\
# \end{align}
#
# \begin{align}
#    \frac {ΔP^e}{ΔY^e}\ & = - K
# \end{align}
#
# \begin{align}
#    ΔY &< 0
# \end{align}
#
# 3.  Effects on the interest rate (r)
#
# \begin{align}
#    \ ΔP^e &= - (-jΔr)
# \end{align}
#
# \begin{align}
#    \frac {ΔP^e}{Δr}\ & = j
# \end{align}
#
# \begin{align}
#    \ Δr &> 0
# \end{align}

# %% [markdown]
# * 2.5

# %%
import numpy as np              
import matplotlib.pyplot as plt

Y_size = 100
           
k = 20                
j = 12           
Ms = 1000           
P  = 30              

Y = np.arange(Y_size)

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_0 = i_LM_0( k, j, Ms, P, Y)
#------------------------------------
Y_size = 100            
k = 20              
j = 12             
Ms = 8000         
P  = 15              

Y = np.arange(Y_size)  

def i_LM_0( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM
i_1 = i_LM_0( k, j, Ms, P, Y)
#-------------------------------------   

Y_size = 100
c = 50               
b = 0.05                        
m = 0.9           
T = 1                 
I_bar = 50            
G_bar = 50
X_bar = 20             
h = 1  

def i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS

i_2 = i_IS_2(c, b, m, T, I_bar, G_bar, X_bar, h, Y)



Y_size = 100
c = 50                
b = 0.01               

m = 0.9          
T = 1                 
I_bar = 20           
G_bar = 50             
X_bar = 10            
h = 1               

Y = np.arange(Y_size)  

def i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y):
    i_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - (1-b+m)*Y)/h
    return i_IS

def Y_IS(c, b, m, T, I_bar, G_bar, X_bar, h, i):
    Y_IS = ((c)-(b-m)*T + I_bar + G_bar + X_bar - h*i)/(1-b+m)
    return Y_IS


i = i_IS(c, b, m, T, I_bar, G_bar, X_bar, h, Y)
#---------------------------------------------------


y_max = np.max(i_0)

v = [0, Y_size, 0, y_max]                     
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Effects of an increase in the Potential Product (dY > 0)", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, i_0, "b-", linestyle='solid', label="LM_0")
ax.plot(Y, i, "b-",linestyle='solid', label="IS_0")
ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
ax.plot(Y, i_1, "r-",linestyle='dashed', color= "orange")
ax.vlines(x=37.5, ymin=-100, ymax=62,linestyle='dotted', colors='black')
ax.hlines(y=59, xmin=-8, xmax=38.5,linestyle='dotted', colors='black')
ax.hlines(y=38, xmin=-8, xmax=50,linestyle='dotted', colors='black')
ax.vlines(x=49.5, ymin=-100, ymax=39,linestyle='dotted', colors='black')
plt.text(20, 100, 'DA', color='black')
plt.text(20, 25, "OA", color='black')
plt.text(20, -30, "OA'", color='black')
ax.yaxis.set_major_locator(plt.NullLocator())  
ax.xaxis.set_major_locator(plt.NullLocator())

plt.plot(50, 42, marker="o", color="midnightblue", label = "Eo_Ÿ")
plt.text(47, 48, 'Eo_Ÿ', fontsize = 14, color = 'midnightblue')

plt.text(45, 20, '→', fontsize=18, color='grey')
plt.text(20, 50, '↓', fontsize=18, color='grey')

plt.text(75, 115, '∆Ÿ', fontsize=12, color='black')
plt.text(76, 110, '→', fontsize=15, color='grey')

plt.plot(38, 64, marker="o", color="black", label = "Eo")
plt.text(36,69, 'Eo', fontsize = 14, color = 'black')
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/983579428.py:85: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_0, "b-", linestyle='solid', label="LM_0")
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/983579428.py:86: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i, "b-",linestyle='solid', label="IS_0")
# C:\Users\HP\AppData\Local\Temp/ipykernel_21992/983579428.py:87: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(Y, i_2, "r-",linestyle='none', color= "orange")
# ...

# %% [markdown]
# * Intuition
#
# 1. Effects on the interest rate (r)
#
# \begin{align}
# (Y- Y_f)↑ - \frac {M^s}{P}\ ↑ - \frac {M^s}{P}\ > Md - r↓
# \end{align}
#
# The marginal product increases, and this makes the money supply to increase too. In this way, the money supply is greater than the demand for money. So, to return to aequilibrium, the interest rate is has to reduce.
#
# 2. Effects on the GDP (Y)
#
# \begin{align}
# r↓ - I↑ - DA↑ > Y - Y↑
# \end{align}
#
# because of the fall in the interest rate, the investment and the aggregate demand increases. In this way, the aggregate demand becomes greater that the level of production. So,to return to equilibrium, the level of production has to increase.
#
# 3. Efeccts on the level of prices (P)
#
# Because of the inverse relationship between prices and the level of production, the decrease in the price will casuse an increase in the level of production:
#
# \begin{align}
# (Y- Y_f)↑ - Y ↑ - P ↓
# \end{align}
#
#
# * Math
#
# 1. Efeccts on the level of prices (P)
#
# \begin{align}
#    \ \frac{ΔP}{ΔP^e} = \frac{-j[1 - b(1 - t)] - hk}{|A|} > 0
# \end{align}
#
# \begin{align}
#    ΔP &>0
# \end{align}
#
# 2. Effects on the GDP (Y)
#
# \begin{align}
#    \frac{ΔY}{ΔP^e} = \frac{hMo^s}{|A|P_o^2} < 0
# \end{align}
#
# \begin{align}
#    ΔY &<0
# \end{align}
#
# 3. Effects on the interest rate (r)
#
# \begin{align}
# \frac{Δr}{ΔP^e} = \frac{-[1 - b(1 - t)]Mo^s}{|A|P_o^2} > 0
# \end{align}
#
# \begin{align}
#    \ Δr &> 0
# \end{align}
