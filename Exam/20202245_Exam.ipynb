# %%
# MIDTERM EXAM

# %%
# MELANY RODRIGUEZ

# %%
# 20202245

# %% [markdown]
# 1. Suppose you are given the following information for the country Poldan:
# TOTAL POPULATION: 175 MILLONES
# GDP PER WORKER: €29,166.667
# GDP PERCAPITA: €15,500
#
# - What is Poldan’s GDP?
# GDP= €15,500 * 175 000 000
# GDP= €2 712 500 000
#
# - What is the number of employed people in Poldan?
# NUMBER OF EMPLOYMENT PEOPLE: €2 712 500 000 / €29,166.667
# NUMBER OF EMPLOYMENT PEOPLE: 92 999 998.9371
# NUMBER OF EMPLOYMENT PEOPLE: 92 999 999 personas empleadas
#
# 2. The following table gives you the same information for the country, Manyger.
# Manyger
# Total population:  89 million
# Employment:   51 million
# GDP:  €2.200 billion
#
# - What is Manyger’s GDP per capita?
# GDP PC= PBI/POBLACION
# GDP PC= €2 200 000 000 / 89 000 000
# GDP PC= €24,719
#
# - What is Manyger’s GDP per worker?
# GDP PER WORKER= GDP/ NUMBER OF PEOPLE IN EMPLOYMENT
# GDP PER WORKER= €2 200 000 000 / 51 000 000
# GDP PER WORKER= €43,137.254.902
#
# - Based on the given information, which country would be considered more productive? Explain your answer.
#
# As is known, if we want to know which country is more productive, we should focus on GDP per worker, since this considers factors such as the population that contributes to the economy with production, thus excluding the elderly and children. With this, we can see which country is more productive than the other.
# Based on the results, the country with the highest productivity is the Manyger country since the GDP per worker is higher than in the Poldan country.
# At first glance, it could be said that the Poldan country is more productive, however, relying only on the number of workers is a bad indicator since not all workers are the same. Some have more human capital, so their skills are different and their productivity too. It is also necessary to take into account that the physical capital and technology may not be the same for both countries, one may invest more in it than the other. With this we can conclude that the Manyger country is more productive since its workers have more human capital than the Poldan country and possibly, the Manyger country invests more in physical capital and has more technology.
#
# - Which country do you think has higher living standards?
#
# On the other hand, the country with the highest living standards is the Manyger country again, since its GDP per capita is higher than that of the first country. However, there are other factors such as inequality, poverty, human development, among others that may not be reflected in the GDP per capita. Despite this, GDP per capita can mostly give us an idea of it, so it continues to be a useful measure to predict this factor.

# %% [markdown]
# 3. In this question, we will use what you learned in Lectures 3 and 4 to compare the performance of an economy in two different time periods, as its physical capital stock and efficiency units of labor change.
# - Suppose that from period 1 to period 2, the unemployment rate in the economy decreases. Everything else remains unchanged. What happens to the total efficiency units of labor? Express your results formally as an inequality, using the formula for total efficiency units of labor presented in the chapter (in particular, recall that total efficiency units of labor in two periods can be written as H1 = L1 * h1 and H2 = L2 * h2; where L is the total number of employed workers).
#
# If the unemployment rate decreases and everything else remains the same, the labor force increases and, therefore, the total efficiency units of labor also increase.
#
# In other words, this last equation is greater than the first:
#
# H2 = L2 * h2 > H1 = L1 * h1
#
# specifically the value of the increase in labor: H2>H1
#
# - What are the consequences of this decrease in unemployment for GDP? Express your results formally as an inequality, using the aggregate production function presented in the chapter.
#
# If unemployment decreases, obviously GDP increases. Based on the production function, the consequences of the decrease in unemployment for GDP with the following:
#
# Y=A*K^1/3*H^2/3
# GDP= A * K^1/3 * H^2/3
# GDP2= A * K^1/3 * H^2/3
# We use a variable that represents the change of the variables with the decrease in unemployment: D
# GDP2= A * KD^1/3 * HD^2/3
# GDP2= D(A * K^1/3 * H^2/3)
# GDP2= D(GDP)
#
# With that we can express that the new GDP, that is, GDP2 is greater than the original GDP:
# GDP2>GDP
#
# - What are the consequences for GDP per capita and GDP per worker?
#
# Since the GDP increased, obviously the GDP per capita also, since to get it out you must divide the GDP by the total population, if there is an increase in the GDP, the GDP per capita will also rise. In the same way for the GDP per worker since an increase in the GDP also affects it when obtained with the division of GDP with the number of workers.
#
# - Suppose that there is a technological advance from period 1 to period 2 and, at the same time, an increase in physical capital stock? Can you say whether GDP will increase or decrease? Why or why not?
#
# It can be said that it will increase because if there is a technological advance, it will increase the productivity of workers, so the value of the marginal product will rise. On the other hand, if there is also an increase in physical social capital, GDP should also rise. So if there is an increase in both variables, there is an increase in GDP.

# %% [markdown]
# 4. Currently, some of the fastest-growing countries in the world remain desperately poor. For example, of the top five fastest-growing economies in 2016, three—Iraq, Burma, and Nauru—had real per capita GDPs that are 101st, 162nd, and 112th in the world, respectively. (Source: CIA, The World Factbook estimates for 2016, PPP basis.) This seems like something of a contradiction. Using the equations for growth given in lectures 3 & 4, explain why a country that has a very low real per capita GDP can also have a very high growth rate.
#
# Growth rate is the change in a quantity between two dates relative to the reference quantity. The formula is Growtht(t+1)= Yt+1 - Yt / Yt
# Based on the exponential nature of growth, two countries may differ over time due to increased growth rates. For example, country A may have a GDP per capita lower than country B, however, the former has a growth rate of 3% as opposed to 1% in the latter. Over the years, this difference increases and the time will come when country A equals country B since its growth is exponential and finally it will surpass it.
# To use the formulas we can illustrate the example as follows:
#
# COUNTRY A
# GROWTH RATE: 3%
# Y2020= 2
# Y2070= ?
# CONSTANT GROWTH: 0.3
#
# 0.03 = Y2021 - Y2020 / Y2020
# 0.03 = Y2021 - 2 / 2
# 1(0.03) = Y2021 - 2
# Y2021= 1.03
# 50(0.03)= 1.5
# Y2070 = 2.5
#
# However, this would be wrong because we must start from the previous year each time.
#
# 0.03= Y2002-Y2021/Y2021
# Y2022= (1.03) (1.03)
# Y2022 = 1.0609
# Y para encontrarlo directamente
# Y2030= (1.03)^50
# Y2030= 4.38391
#
# On the other hand, for country B, which we suppose, it has twice what country A started with, but it has a growth rate of 1%
#
# COUNTRY B
# GROWTH RATE: 1%
# Y2020= 2
# Y2070= ?
# CONSTANT GROWTH: 0.1
#
# 0.01= Y2020-Y2021/Y2021
# Y2022= (2.01) (2.01)
# Y2022 = 4.0401
#
# Y2070= (2.01)^50
# Y2070= 1.44478
#
# With this, we realize that despite the fact that country A started with a lower value, it has a higher growth rate than country B and that the latter, despite starting with twice the initial value, has a lower growth than the first country. Therefore, it is stated that a country can have a lower GDP per capita but a high growth rate, which over the years, increases its initial value with respect to others.

# %% [markdown]
# 5. Increasingly, independent programmers are making their code “open source.” The programming language “Python,” for example, is completely free and open; anyone can submit a new package of specialized functions. How might open-source technology affect growth in developing countries? Imagine every technology company in the United States suddenly made their code open-source; would this increase growth in developing countries? Explain.
#
# Yes, with the help of open source, users around the world can modify and use the supported feature packs. This helps collaborators to improve the code and together build an increasingly elaborate one. At a macroeconomic level, I consider that the advantages are greater than the disadvantages, since it also has them. First of all, it does influence the economy of a country. This is intertwined with how much a country uses technology. Developing countries could take advantage of it very well, but most of them lack the means to do so or simply do not care. So open source in these contexts might not have short-term effects. In addition to this, if the open source, being free and easily accessible, could reduce the purchase of closed source programs, which would negatively influence the GDP if it is a country in which the closed source prevails. On the contrary, with the use of open source, companies could use it and their workers could increase their productivity, which would eventually be reflected in GDP. With this we see that there are advantages and disadvantages. Second, countries that take better advantage of technology, which are mostly developed countries like the United States. If companies from this country made their codes open, this would benefit developing countries since, as mentioned above, companies from other countries could include it and increase their productivity at work, so the PNI would improve. On the other hand, the companies that were paid for the previously closed code will have losses and this will be reflected in the GDP of the country of origin, the United States. For the most part, the level of affectation of this new policy to developing countries depends on how much they use the technology and how much closed source they have been using.

# %% [markdown]
# 6. The following table shows the employment level, unemployment level, and the labor force participation rate in Greece for the month of March of every year from 2008 to 2020. Use the given data to complete the table and answer the following questions. (Note: All rates are in percent.) Fill the table using Python. And answer the questions below.

# %%
import pandas as pd
import numpy as np

# %%
data0= pd.read_excel('P6.xlsx')

# %%
data0
# Out:
#     Year   Number\nUnemployed\n(in thousands)  \
# 0    2008                            454.1000
# 1    2009                            475.1000
# 2    2010                            594.9000
# 3    2011                            828.3000
# 4    2012                           1130.4000
# 5    2013                           1302.8000
# 6    2014                           1343.4000
# 7    2015                           1299.4000
# 8    2016                           1189.9000
# 9    2017                           1079.7170
# 10   2018                            973.5729
# 11   2019                            844.0380
# 12   2020                            665.3619
#
#     Number\nEmployed\n(in thousands)  Labor Force\nParticipation\nRate (%)  \
# 0                          4537.4000                                 52.90
# 1                          4535.5000                                 53.20
# 2                          4432.1000                                 53.60
# ...

# %% [markdown]
# - In which years did the economy witness increases in the unemployment rate? What could possibly explain this?
#
# The years in which the unemployment rate rises are between 2013 and 2015, between those years the unemployment rate rises to 27%, after and before those years the unemployment rate is lower. The factors that could influence this are an economic recession which rapidly increases unemployment. However, because the unemployment rate does not increase exponentially and rapidly, on the contrary it is progressive and growing up to a point in 2014 where it peaked, a possible rigid wage policy cannot be ruled out since it can generate a shift to the left of the labor demand curve, thus creating a greater decrease in employment, generating greater unemployment.
#
# - Use the data on the size of the labor force and potential workers to compute the percentage of adults out of the labor force for the year 2017. Verify that your calculation is equal to one minus the labor force participation rate.
#
# 2017
# Labor force = 4748.9142
# Aduld population = 9150.123699
# Non labor force= 9150.123699 - 4748.9142
# Non labor force = 4401.209499
# Non Labor force participation rate = 100% (Labor force / Potential workers)
# NLFPR= 100%(Non labor force/Potential workers)
# NLFPR= 100%(4401.209499/9150.123699)
# NLFPR= 100%(0.481)
# NLFPR= 48.10%
#
# The percentage of adults outside the labor force for the year 2017 is 48.1%
#
# - What are the general trends that you observe in the data?
# In general it can be seen that the unemployment rate has been going down since a peak in 2014, despite the pandemic, the unemployment rate did not go up and continues to go down until a future where the rate is healthy for the country. On the other hand, the population that participates in production and forms part of the labor force is almost 50% for each one, which tells us that half of the total population of working age does not do so, which is worrying in many ways.

# %% [markdown]
# 7. Assume that 1 million immigrants enter Peru from Venezuela this year and that some of these immigrants work in the home construction industry. Graph the impact of immigration on the supply of labor and the resulting new equilibrium wage and quantity.
#
# First, due to Venezuelan immigrants, there is a shift in the supply curve. Venezuelan immigrants increase the size of the population, especially of potential workers in the economy since some of them work in housing construction. This shifts the labor supply curve to the right.
# Second, regardless of the demand curve for labor, the shift in the supply curve for labor obviously changes the equilibrium in wage and quantity. The new equilibrium shifts to the right and down. There is more labor supplied but the same labor demanded so the wage is pushed down.

# %%
from IPython.display import Image
Image(filename='curve1.jpeg')

# %%
Image(filename='curve2.jpeg')

# %%
Image(filename='equilibrium.jpeg')

# %% [markdown]
# - These new immigrants also increase the demand for housing. Graph the change in the demand for labor in the home construction industry due to the increased demand for housing.
#
# Immigrants, by increasing the demand for housing, cause the price of housing to rise. So it belongs to a change in the production market. The demand curve for labor in the housing construction industry shifts to the right, that is, upwards, since it generates an increase in the value of the marginal product of the industry.
#
# - Without considering the increase in the supply of labor, how does the equilibrium wage and quantity of workers hired change?
#
# If we don't take into account the increase in the supply of labor, we would take into account the change in demand. Immigrants increase the demand for housing and the demand curve shifts to the right. With this, the balance changes and as the labor supplied is less than that demanded, the wage increases.
#
# - Considering both the change in the supply and the demand for labor in the home construction industry, what can you conclude about the change in the equilibrium wage and quantity of workers hired?
#
# Taking both labor curves into account, we can conclude the following: since immigrants increase the demand for housing and in turn increase the supply of labor, the labor supply and demand curves shift to the right . This generates a new equilibrium in wages and the number of workers, this new equilibrium is located to the right. The new equilibrium brings the previous wage to immigrants back to a stable level.

# %%
data1 = "https://raw.githubusercontent.com/Alejangro19/Macro/main/njmin3_1.csv"
data = pd.read_csv(data1)
data
# Out:
#      CO_OWNED  SOUTHJ  CENTRALJ  PA1  PA2   DEMP  nj  bk  kfc  roys  wendys  \
# 0           0       0         1    0    0  12.00   1   1    0     0       0
# 1           0       0         1    0    0   6.50   1   1    0     0       0
# 2           0       0         1    0    0  -1.00   1   0    0     1       0
# 3           1       0         0    0    0   2.25   1   0    0     1       0
# 4           0       0         0    0    0  13.00   1   1    0     0       0
# ..        ...     ...       ...  ...  ...    ...  ..  ..  ...   ...     ...
# 815         1       0         0    0    1  -2.50   0   0    0     1       0
# 816         0       0         0    0    1  16.00   0   0    0     1       0
# 817         1       0         0    0    1 -10.25   0   0    0     1       0
# 818         0       0         0    1    0  -1.50   0   1    0     0       0
# 819         0       0         0    1    0  -3.50   0   1    0     0       0
#
#      d  d_nj    fte
# 0    0     0  15.00
# ...

# %%
model = smf.ols(formula = "fte ~ d_nj + kfc + roys + wendys + CO_OWNED + SOUTHJ + CENTRALJ + PA1", data = data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    fte   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     27.47
# Date:                Sat, 21 May 2022   Prob (F-statistic):           9.44e-38
# Time:                        14:37:51   Log-Likelihood:                -2809.2
# No. Observations:                 794   AIC:                             5636.
# Df Residuals:                     785   BIC:                             5679.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.3532      0.601     40.549      0.000      23.174      25.532
# ...

# %%
NJ_before = data.loc[(data['nj']==1) & (data['d']!=1),'fte'].mean()
NJ_after  = data.loc[(data['nj']==1) & (data['d']==1),'fte'].mean()

PA_before = data.loc[(data['nj']!=1) & (data['d']!=1),'fte'].mean()
PA_after  = data.loc[(data['nj']!=1) & (data['d']==1),'fte'].mean()

NJ_counterfactual = NJ_before + ( NJ_before - PA_before )

[NJ_before, NJ_after,
 PA_before,PA_after,
 NJ_before, NJ_counterfactual]
# Out:
# [20.439408099688475,
#  21.02742946708464,
#  23.33116883116883,
#  21.165584415584416,
#  20.439408099688475,
#  17.547647368208118]

# %%
plt.figure(num=None, figsize=(4, 3), dpi=80, facecolor='w', edgecolor='k')
fig, ax = plt.subplots()
lineNJ, = ax.plot(['0', '1'], [NJ_before, NJ_after],color='blue',label='NJ before and after')
linePA, = ax.plot(['0', '1'], [PA_before, PA_after],color = 'red',label = 'PA before and after')
lineNJ0, = ax.plot(['0', '1'], [NJ_before, NJ_counterfactual],color = 'blue',linestyle='dashed',label='NJ counterfactual')
ax.legend()
plt.ylim(15, 28)  
plt.title("Difference-in-difference: Before and After", fontsize="14")
# Out:
# Text(0.5, 1.0, 'Difference-in-difference: Before and After')

# %% [markdown]
# - ¿El salario mínimo tiene un impacto en el empleo?
#
# According to the document Card and Kruger conclude that the increase in the minimum wage does not show any reduction in employment. There is no evidence that increasing New Jersey's minimum wage reduces employment in fast food restaurants. On the contrary, we find that the increase in the minimum wage increased employment. So the minimum wage does have a positive impact on employment.
#
# - ¿Cuál es el método de diferencia y diferencia y explicar en detalle utilizando figuras y/o ecuaciones?
#
# The method consists of an early quasi-experimental research strategy to estimate causal effects. To do this, we calculated the difference in the mean result between the groups in the previous period.
# Then the second difference is taken, which is the sum between the first difference and the difference between the differences.
# This last difference measures how much the change in the result differs between the two groups.
#
# According to the document, with the adjusted regression model, in this way:
#
# (1a) AEi = a+bXi+cNJi+ei
# (lb) AEi = a'+b'Xi+c'GAPi+e'i
# AE is the change in employment from wage 1 to wage 2
# the store is i,
# Xi is a set of characteristics of store i,
# NJ, is a dummy variable that equals 1 for stores in New Jersey.
# GAP, is an alternative measure of the impact of the minimum wage at store i based on the initial wage at that store (W1i):
#
# GAPi = 0 = for stores in Pennsylvania
#      = 0 = for stores in New Jersey with
#      W1i≥ $5.05
#      =($5.05 - W1i) W1i   for other stores in New Jersey
#
# - ¿Cómo se utiliza este método para calcular el impacto del salario mínimo en el empleo?
#
# After analyzing the objective of the study, that is, the 410 fast food restaurants in New Jersey and Pennsylvania after the increase from $4.25 to $5.05 per hour.
# They compared full-time equivalent employment in New Jersey and Pennsylvania before and after the minimum wage increase.
# Restaurants in New Jersey are defined as the treatment group and those in Pennsylvania as the control group.
# Based on the previous question, and through the tables shown, it is stated that the GAP variable is used to measure the effect of the minimum wage. Whose result of the mean value of GAPi among stores in New Jersey is 0.11. Which implies a 1.72 increase in FTE employment in New Jersey relative to Pennsylvania. Dummy variables identify the effect of the minimum wage for changes in higher and lower wage employment within the same region of New Jersey.
# In addition, it implies that the increase in minimum wages increased employment in New Jersey stores that initially paid $4.25 an hour by 14 percent.
